# %% [markdown]
# # Locations
#
# This step explores and cleans the locations.</br>
# Locations without area are dropped. Area is converted to km2.
# At the end, the result is written to a .parquet file to preserve the data types

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import numpy as np

# set the max columns to none
pd.set_option('display.max_columns', None)
# set the max columns to none
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Data exploring

# %%
file = f'../1_scraping/scraped_data/cleaned/location_details_clean.csv'

# Load the data
df_locations = pd.read_csv(file, header=0, index_col="location_id")

# Preview
df_locations.head(5)
# Out:
#                               location_name         province  province_id  \
# location_id
# 241620                            A Fladjon            Liège         22.0
# 252470       A la Creux (réserve naturelle)       Luxembourg         26.0
# 241688                         A St-Jacques            Namur         24.0
# 27478                           Aaigem (Dg)  Oost-Vlaanderen         16.0
# 31885                  Aalbeke - Allartpark  West-Vlaanderen         15.0
#
#                      municipality  municipality_id location_type  page  \
# location_id
# 241620               Ans (entité)          43743.0        Gebied     1
# 252470           Léglise (entité)          43953.0        Gebied     1
# 241688       Somme-Leuze (entité)          43891.0        Gebied     1
# 27478                   Erpe-Mere          24153.0  Deelgemeente     1
# 31885                Aalbeke (Dg)          24033.0        Gebied     1
#
#                  area
# location_id
# 241620       4.780 m2
# 252470       18,13 ha
# 241688       30,22 ha
# 27478        7,41 km2
# 31885         2,16 ha

# %%
df_locations.index
# Out:
# Index([241620, 252470, 241688,  27478,  31885,  71763,  83947,  24033, 724399,
#         83946,
#        ...
#         29903, 191328,  28347, 191310,  29933,  29905, 191315,  29906,  29904,
#         28705],
#       dtype='int64', name='location_id', length=14040)

# %%
df_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14040 entries, 241620 to 28705
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   location_name    14040 non-null  object
#  1   province         14040 non-null  object
#  2   province_id      14039 non-null  float64
#  3   municipality     14040 non-null  object
#  4   municipality_id  13646 non-null  float64
#  5   location_type    14040 non-null  object
#  6   page             14040 non-null  int64
#  7   area             13966 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 987.2+ KB

# %%
df_locations.describe(include='all')
# Out:
#                                         location_name         province  \
# count                                           14040            14040
# unique                                          13994               12
# top     Ancienne Carrière de l'Eau Bleue (La Bruyère)  Oost-Vlaanderen
# freq                                                2             2270
# mean                                              NaN              NaN
# std                                               NaN              NaN
# min                                               NaN              NaN
# 25%                                               NaN              NaN
# 50%                                               NaN              NaN
# 75%                                               NaN              NaN
# max                                               NaN              NaN
#
#          province_id municipality  municipality_id location_type  \
# count   14039.000000        14040     13646.000000         14040
# unique           NaN          716              NaN             4
# top              NaN            —              NaN        Gebied
# freq             NaN          394              NaN         10895
# mean       19.169243          NaN     33974.214568           NaN
# std         3.881507          NaN     15465.777904           NaN
# min        14.000000          NaN     23089.000000           NaN
# 25%        16.000000          NaN     23441.000000           NaN
# 50%        17.000000          NaN     24169.500000           NaN
# 75%        23.000000          NaN     43850.000000           NaN
# max        26.000000          NaN     91762.000000           NaN
#
#                 page     area
# count   14040.000000    13966
# unique           NaN     7152
# top              NaN  1,1 km2
# freq             NaN       25
# mean      281.300214      NaN
# std       162.125842      NaN
# min         1.000000      NaN
# 25%       141.000000      NaN
# 50%       281.000000      NaN
# 75%       422.000000      NaN
# max       562.000000      NaN

# %% [markdown]
# ## Cleaning

# %%
df_locations_cleaned = df_locations.copy()

# %% [markdown]
# ### Area
# Only keep locations with a valid area. Transform everything to km2

# %%
df_locations_cleaned = df_locations_cleaned.dropna(subset = ['area'])

# %%
def transform_area_to_km2(area):
    area_value = area.split(" ")[0]
    area_value = area_value.replace(".", "")
    area_value = area_value.replace(",", ".")
    
    area_unit = area.split(" ")[1]
    if area_unit == "ha":
        area_value = float(area_value) / 100
    elif area_unit == "km2":
        area_value = float(area_value)
    elif area_unit == "m2":
        area_value = float(area_value) / 1000000
    elif area_unit == "a":
        area_value = float(area_value) / 10000
    else:
        raise ValueError(f"Unknown area unit: {area_unit}")
    return area_value
    

df_locations_cleaned["area_km2"] = df_locations_cleaned["area"].apply(lambda x: transform_area_to_km2(x))

# %%
df_locations_cleaned[df_locations_cleaned["area"].str.contains(".", regex=False)].head(5)
# Out:
#                                                  location_name  \
# location_id
# 241620                                               A Fladjon
# 126250       Aarschot - Sleedoornpage - Biezenhuiskes - Hou...
# 126249       Aarschot - Sleedoornpage - Biezenhuiskes - Hou...
# 191799        Aarsele - Spoorweg tssn overgang N459 en veldweg
# 191595       Aarsele - Spoorwegberm voorbij overgang tot pa...
#
#                     province  province_id  municipality  municipality_id  \
# location_id
# 241620                 Liège         22.0  Ans (entité)          43743.0
# 126250        Vlaams-Brabant         20.0      Aarschot          23400.0
# 126249        Vlaams-Brabant         20.0      Aarschot          23400.0
# 191799       West-Vlaanderen         15.0         Tielt          24063.0
# 191595       West-Vlaanderen         15.0         Tielt          24063.0
#
#             location_type  page      area  area_km2
# location_id
# 241620             Gebied     1  4.780 m2  0.004780
# 126250             Gebied     3  1.724 m2  0.001724
# 126249             Gebied     3  1.065 m2  0.001065
# 191799             Gebied     3  2.869 m2  0.002869
# 191595             Gebied     3  8.480 m2  0.008480

# %%
df_locations_cleaned[df_locations_cleaned["area"].str.contains(",")].head(5)
# Out:
#                               location_name         province  province_id  \
# location_id
# 252470       A la Creux (réserve naturelle)       Luxembourg         26.0
# 241688                         A St-Jacques            Namur         24.0
# 27478                           Aaigem (Dg)  Oost-Vlaanderen         16.0
# 31885                  Aalbeke - Allartpark  West-Vlaanderen         15.0
# 71763                     Aalbeke - Potyzer  West-Vlaanderen         15.0
#
#                      municipality  municipality_id location_type  page  \
# location_id
# 252470           Léglise (entité)          43953.0        Gebied     1
# 241688       Somme-Leuze (entité)          43891.0        Gebied     1
# 27478                   Erpe-Mere          24153.0  Deelgemeente     1
# 31885                Aalbeke (Dg)          24033.0        Gebied     1
# 71763                Aalbeke (Dg)          24033.0        Gebied     1
#
#                  area  area_km2
# location_id
# 252470       18,13 ha    0.1813
# 241688       30,22 ha    0.3022
# 27478        7,41 km2    7.4100
# 31885         2,16 ha    0.0216
# 71763         2,08 ha    0.0208

# %%
df_locations_cleaned.drop(columns=["area"], inplace=True)

# %% [markdown]
# ## Final check and write to parquet file

# %%
df_locations_cleaned.head(20)
# Out:
#                                                  location_name  \
# location_id
# 241620                                               A Fladjon
# 252470                          A la Creux (réserve naturelle)
# 241688                                            A St-Jacques
# 27478                                              Aaigem (Dg)
# 31885                                     Aalbeke - Allartpark
# 71763                                        Aalbeke - Potyzer
# 83947                           Aalbeke - Vijver Vandecasteele
# 24033                                             Aalbeke (Dg)
# 724399                  Aalbeke/Marke - Kobbepoel, Preshoekbos
# 83946                  Aalbeke/Marke - Preshoekbos en omgeving
# 24142                                                    Aalst
# 675646                                   Aalst - Begraafplaats
# 247762                                     Aalst - Bergenmeers
# 259782                             Aalst - Buurtpark Ten Rozen
# 192700                                      Aalst - Kravaalbos
# 192702                           Aalst - Kravaalkouters - Oost
# 192703                           Aalst - Kravaalkouters - West
# 142900                        Aalst - Kravaalkouters (globaal)
# 251974                                     Aalst - Mijlbeekbos
# 613791       Aalst - Molenbeek-Graadbeek (Prov. Oost-Vlaand...
#
#                     province  province_id          municipality  \
# location_id
# 241620                 Liège         22.0          Ans (entité)
# 252470            Luxembourg         26.0      Léglise (entité)
# 241688                 Namur         24.0  Somme-Leuze (entité)
# 27478        Oost-Vlaanderen         16.0             Erpe-Mere
# 31885        West-Vlaanderen         15.0          Aalbeke (Dg)
# 71763        West-Vlaanderen         15.0          Aalbeke (Dg)
# 83947        West-Vlaanderen         15.0              Kortrijk
# 24033        West-Vlaanderen         15.0              Kortrijk
# 724399       West-Vlaanderen         15.0              Kortrijk
# 83946        West-Vlaanderen         15.0          Aalbeke (Dg)
# 24142        Oost-Vlaanderen         16.0                     —
# 675646       Oost-Vlaanderen         16.0                 Aalst
# 247762       Oost-Vlaanderen         16.0                 Aalst
# 259782       Oost-Vlaanderen         16.0                 Aalst
# 192700       Oost-Vlaanderen         16.0                 Aalst
# 192702       Oost-Vlaanderen         16.0                 Aalst
# 192703       Oost-Vlaanderen         16.0                 Aalst
# 142900       Oost-Vlaanderen         16.0                 Aalst
# 251974       Oost-Vlaanderen         16.0                 Aalst
# 613791       Oost-Vlaanderen         16.0                 Aalst
#
#              municipality_id location_type  page  area_km2
# location_id
# 241620               43743.0        Gebied     1   0.00478
# 252470               43953.0        Gebied     1   0.18130
# 241688               43891.0        Gebied     1   0.30220
# 27478                24153.0  Deelgemeente     1   7.41000
# 31885                24033.0        Gebied     1   0.02160
# 71763                24033.0        Gebied     1   0.02080
# 83947                24030.0        Gebied     1   0.20790
# 24033                24030.0  Deelgemeente     1   7.35000
# 724399               24030.0        Gebied     1   0.05340
# 83946                24033.0        Gebied     1   4.09000
# 24142                    NaN      Gemeente     1  78.59000
# 675646               24142.0        Gebied     1   0.08170
# 247762               24142.0        Gebied     1   0.09760
# 259782               24142.0        Gebied     1   0.05550
# 192700               24142.0        Gebied     1   1.59000
# 192702               24142.0        Gebied     1   2.40000
# 192703               24142.0        Gebied     1   0.62190
# 142900               24142.0        Gebied     1   3.39000
# 251974               24142.0        Gebied     1   0.42470
# 613791               24142.0        Gebied     1  25.69000

# %%
df_locations_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13966 entries, 241620 to 28705
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   location_name    13966 non-null  object
#  1   province         13966 non-null  object
#  2   province_id      13965 non-null  float64
#  3   municipality     13966 non-null  object
#  4   municipality_id  13572 non-null  float64
#  5   location_type    13966 non-null  object
#  6   page             13966 non-null  int64
#  7   area_km2         13966 non-null  float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 982.0+ KB

# %%
df_locations_cleaned.to_parquet(f'./clean_data/locations_clean.parquet', index=True, engine="pyarrow")
