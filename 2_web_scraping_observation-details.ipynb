# %%
import bs4
import requests
import pandas as pd
from datetime import datetime
import time
import os
from random import randint

# Base URL for scraping
base_url = 'https://waarnemingen.be/observation/{}/'  

# Function to parse a single page
def parse_observation(observation_id, retries=10, backoff_factor=2):
    headers = {
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36",
        "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
        "accept-encoding":"gzip, deflate, br, zstd",
        "accept-language":"nl-BE,nl;q=0.9,en-BE;q=0.8,en;q=0.7,nl-NL;q=0.6,en-US;q=0.5",
        "connection":"keep-alive",
        "cookie":"csrftoken=3JbFPYJyRC9GxhkNoW4XzF1vbbG6Fbxe; sessionid=v132os9mxwltj3ol3plhmojrjch24m9o; fundraiser_dismissed=1; cookielaw_accepted=1",
        "host":"waarnemingen.be",
        "Referer": "https://www.google.com/",
        "sec-ch-ua":'"Not A(Brand";v="8", "Chromium";v="132", "Google Chrome";v="132"',
        "sec-ch-ua-mobile":"?0",
        "sec-ch-ua-platform":"Linux",
        "sec-fetch-dest":"document",
        "sec-fetch-mode":"navigate",
        "sec-fetch-site":"same-origin",
        "sec-fetch-user":"?1",
        "upgrade-insecure-requests":"1"
            }
    for attempt in range(retries):
        try:
            res = requests.get(base_url.format(observation_id), headers=headers)
            print(f"Requesting {base_url.format(observation_id)}")
            res.raise_for_status()
            soup = bs4.BeautifulSoup(res.text, 'html.parser')
            
            observation = {
                "observation_id": observation_id,
                "species_id": soup.select_one("h1 > a").get('href').split('/')[2],
                "species_name": soup.select_one(".species-common-name").getText().strip(),
                "species_name_scientific": soup.select_one(".species-scientific-name").getText().strip(),
                "validation": soup.select_one(".validation-status-text").getText().strip(),
                "gps_coordinates": soup.select_one('span[title="WGS 84"] .teramap-coordinates-coords').getText().strip() if soup.select_one('span[title="WGS 84"] .teramap-coordinates-coords') else None,
                "accuracy": soup.find('span', string="Nauwkeurigheid").next_sibling.getText().strip() if soup.find('span', string="Nauwkeurigheid") else None,
                "source": soup.find('span', string="Bron").next_sibling.getText().strip() if soup.find('span', string="Bron") else None,
                "date": soup.select_one('th:-soup-contains("Datum") + td').getText().strip() if soup.select_one('th:-soup-contains("Datum") + td') else None,
                "amount": soup.select_one('th:-soup-contains("Aantal") + td').getText().strip() if soup.select_one('th:-soup-contains("Aantal") + td') else None, # aantal
                "life_stage": soup.select_one('th:-soup-contains("Levensstadium") + td').getText().strip() if soup.select_one('th:-soup-contains("Levensstadium") + td') else None, # levensstadium
                "activity": soup.select_one('th:-soup-contains("Activiteit") + td').getText().strip() if soup.select_one('th:-soup-contains("Activiteit") + td') else None, # activiteit
   
                "location_id": soup.select_one('th:-soup-contains("Locatie") + td').a.get('href').split('/')[2] if soup.select_one('th:-soup-contains("Locatie") + td a') else None, 
                "location": soup.select_one('th:-soup-contains("Locatie") + td a').getText().strip() if soup.select_one('th:-soup-contains("Locatie") + td a') else None, # locatie
                "observer_id": soup.select_one('th:-soup-contains("Waarnemer") + td').a.get('href').split('/')[2] if soup.select_one('th:-soup-contains("Waarnemer") + td a') else None,
                "observer_name": soup.select_one('th:-soup-contains("Waarnemer") + td a').getText().strip() if soup.select_one('th:-soup-contains("Waarnemer") + td a') else None, # waarnemer
                
                "counting_method": soup.select_one('th:-soup-contains("Telmethode") + td').getText().strip() if soup.select_one('th:-soup-contains("Telmethode") + td') else None, # telmethode
                "method": soup.select_one('th:-soup-contains("Methode") + td').getText().strip() if soup.select_one('th:-soup-contains("Methode") + td') else None, # methode
            }
            # print(observation)
            return observation
        except requests.exceptions.HTTPError as e:
            print(f"HTTP error: {e} on attempt {attempt + 1}/{retries}")
            if attempt < retries - 1:
                time.sleep(backoff_factor * (2 ** attempt))
                continue
            else:
                raise e
            
def scrape(observations, species_id, folder_path):
    file_name = make_filename(species_id, folder_path)
    # print(f"make_filename: {file_name}")
    
    try:
        for i, observation_id in enumerate(observations):
            if (i == 0 and not os.path.isfile(file_name)):
                write_header = True
                # print(f"Writing header to {file_name}")
            else:
                write_header = False
            
            observation = parse_observation(observation_id)
            pd.DataFrame([observation]).to_csv(
                file_name,
                mode='a',  # Append mode
                index=False,
                header=write_header  # Write header only for the first write in the file
            )
            
            time.sleep(randint(2,10))  # Variable respectful delay between requests

    except Exception as e:
        print(f"An error occurred: {e}")
    
def make_filename(species_id, folder_path, complete=False):
    os.makedirs('scraped_data', exist_ok=True)
    base_name = f'{folder_path}/observation_details_{species_id}_clean'
    if not complete:
        return base_name + '_in_progress.csv'
    else:
        return base_name + '.csv'

###########################################################################################################################################
species_id = 116
folder_path_clean = "./scraped_data/cleaned/"
scrape_amount = 2000

start_time = datetime.now()

df_general = pd.read_csv(folder_path_clean + "observations_general_" + str(species_id) + "_clean" + ".csv")
details = [f for f in os.listdir(folder_path_clean) if f"observation_details_{species_id}_clean" in f and f.endswith(".csv")]

# print(f"{len(details)} details files found {details} ")

df_details = pd.read_csv(folder_path_clean + details[0]) if len(details) > 0 else None

if (df_details is not None):
    # Find ids in df_general that are not in df_details
    not_in_details = df_general[~df_general['id'].isin(df_details['observation_id'])]['id'].tolist()
else:
    not_in_details = df_general['id'].tolist()
    
    
if len(not_in_details) > 0:
    print(f"Start scraping: {scrape_amount} this batch, but {len(not_in_details)} observations to scrape")
    scrape(not_in_details[0:scrape_amount], species_id, folder_path_clean)
else:
    print("All observations have been scraped.")
    os.rename(make_filename(species_id, folder_path_clean, complete=False), make_filename(species_id, folder_path_clean, complete=True))
    
end_time = datetime.now()
execution_time = end_time - start_time

days, rem = divmod(execution_time.total_seconds(), 86400)
hours, rem = divmod(execution_time.total_seconds(), 3600)
minutes, rem = divmod(execution_time.total_seconds(), 60)
seconds, milliseconds = divmod(rem, 1)
print(f"Execution time: {int(days)} days, {int(hours)} hours, {int(minutes)} minutes, {int(seconds)} seconds")
# Out:
# Start scraping: 2000 this batch, but 96857 observations to scrape
# Requesting https://waarnemingen.be/observation/336066135/
# Requesting https://waarnemingen.be/observation/336071611/
# Requesting https://waarnemingen.be/observation/336051299/
# Requesting https://waarnemingen.be/observation/336027209/
# Requesting https://waarnemingen.be/observation/336051296/
# Requesting https://waarnemingen.be/observation/336045707/
# Requesting https://waarnemingen.be/observation/336024604/
# Requesting https://waarnemingen.be/observation/336073878/
# Requesting https://waarnemingen.be/observation/336017716/
# Requesting https://waarnemingen.be/observation/336016944/
# Requesting https://waarnemingen.be/observation/336029158/
# Requesting https://waarnemingen.be/observation/336015242/
# Requesting https://waarnemingen.be/observation/336045294/
# Requesting https://waarnemingen.be/observation/336043081/
# Requesting https://waarnemingen.be/observation/336024816/
# Requesting https://waarnemingen.be/observation/336086727/
# Requesting https://waarnemingen.be/observation/336086718/
# Requesting https://waarnemingen.be/observation/336001677/
# Requesting https://waarnemingen.be/observation/335986529/
# Requesting https://waarnemingen.be/observation/335991493/
# Requesting https://waarnemingen.be/observation/336013186/
# Requesting https://waarnemingen.be/observation/336309494/
# Requesting https://waarnemingen.be/observation/336054041/
# Requesting https://waarnemingen.be/observation/335983197/
# Requesting https://waarnemingen.be/observation/335980033/
# Requesting https://waarnemingen.be/observation/335989302/
# Requesting https://waarnemingen.be/observation/337079112/
# Requesting https://waarnemingen.be/observation/337079089/
# Requesting https://waarnemingen.be/observation/336768124/
# Requesting https://waarnemingen.be/observation/336718882/
# Requesting https://waarnemingen.be/observation/336080757/
# Requesting https://waarnemingen.be/observation/336068669/
# Requesting https://waarnemingen.be/observation/336048897/
# Requesting https://waarnemingen.be/observation/336048139/
# Requesting https://waarnemingen.be/observation/336047681/
# Requesting https://waarnemingen.be/observation/336045655/
# Requesting https://waarnemingen.be/observation/335964832/
# Requesting https://waarnemingen.be/observation/335961475/
# Requesting https://waarnemingen.be/observation/335960422/
# Requesting https://waarnemingen.be/observation/336176808/
# Requesting https://waarnemingen.be/observation/335955835/
# Requesting https://waarnemingen.be/observation/335960319/
# Requesting https://waarnemingen.be/observation/335940824/
# Requesting https://waarnemingen.be/observation/335939096/
# Requesting https://waarnemingen.be/observation/335939137/
# Requesting https://waarnemingen.be/observation/335940821/
# Requesting https://waarnemingen.be/observation/335939258/
# Requesting https://waarnemingen.be/observation/335972823/
# Requesting https://waarnemingen.be/observation/335939272/
# Requesting https://waarnemingen.be/observation/336110485/
# Requesting https://waarnemingen.be/observation/335939306/
# Requesting https://waarnemingen.be/observation/335939374/
# Requesting https://waarnemingen.be/observation/335939430/
# Requesting https://waarnemingen.be/observation/335939463/
# Requesting https://waarnemingen.be/observation/335939457/
# Requesting https://waarnemingen.be/observation/335939502/
# Requesting https://waarnemingen.be/observation/335939555/
# Requesting https://waarnemingen.be/observation/335939552/
# Requesting https://waarnemingen.be/observation/335939590/
# Requesting https://waarnemingen.be/observation/335976052/
# Requesting https://waarnemingen.be/observation/336072268/
# Requesting https://waarnemingen.be/observation/335939614/
# Requesting https://waarnemingen.be/observation/335939620/
# Requesting https://waarnemingen.be/observation/336061045/
# Requesting https://waarnemingen.be/observation/335939635/
# Requesting https://waarnemingen.be/observation/335929902/
# Requesting https://waarnemingen.be/observation/335929549/
# Requesting https://waarnemingen.be/observation/335928863/
# Requesting https://waarnemingen.be/observation/335928360/
# Requesting https://waarnemingen.be/observation/335939670/
# Requesting https://waarnemingen.be/observation/335951217/
# Requesting https://waarnemingen.be/observation/335939707/
# Requesting https://waarnemingen.be/observation/335939714/
# Requesting https://waarnemingen.be/observation/335939733/
# Requesting https://waarnemingen.be/observation/335939749/
# Requesting https://waarnemingen.be/observation/335939794/
# Requesting https://waarnemingen.be/observation/335931917/
# Requesting https://waarnemingen.be/observation/335939827/
# Requesting https://waarnemingen.be/observation/335939844/
# Requesting https://waarnemingen.be/observation/335939869/
# Requesting https://waarnemingen.be/observation/335939899/
# Requesting https://waarnemingen.be/observation/335939962/
# Requesting https://waarnemingen.be/observation/335939990/
# Requesting https://waarnemingen.be/observation/335940032/
# Requesting https://waarnemingen.be/observation/335940027/
# Requesting https://waarnemingen.be/observation/335940036/
# Requesting https://waarnemingen.be/observation/335940044/
# Requesting https://waarnemingen.be/observation/335935950/
# Requesting https://waarnemingen.be/observation/336367845/
# Requesting https://waarnemingen.be/observation/336718871/
# Requesting https://waarnemingen.be/observation/336124849/
# Requesting https://waarnemingen.be/observation/335933256/
# Requesting https://waarnemingen.be/observation/336647467/
# Requesting https://waarnemingen.be/observation/335904789/
# Requesting https://waarnemingen.be/observation/335928395/
# Requesting https://waarnemingen.be/observation/335937595/
# Requesting https://waarnemingen.be/observation/335890706/
# Requesting https://waarnemingen.be/observation/335901874/
# Requesting https://waarnemingen.be/observation/335888214/
# Requesting https://waarnemingen.be/observation/335904275/
# Requesting https://waarnemingen.be/observation/335879467/
# Requesting https://waarnemingen.be/observation/335957358/
# Requesting https://waarnemingen.be/observation/335880129/
# Requesting https://waarnemingen.be/observation/335897237/
# Requesting https://waarnemingen.be/observation/335846918/
# Requesting https://waarnemingen.be/observation/335937793/
# Requesting https://waarnemingen.be/observation/335920196/
# Requesting https://waarnemingen.be/observation/335893685/
# Requesting https://waarnemingen.be/observation/335992628/
# Requesting https://waarnemingen.be/observation/335843419/
# Requesting https://waarnemingen.be/observation/335841991/
# Requesting https://waarnemingen.be/observation/335841454/
# Requesting https://waarnemingen.be/observation/335904837/
# Requesting https://waarnemingen.be/observation/335857083/
# Requesting https://waarnemingen.be/observation/336253015/
# Requesting https://waarnemingen.be/observation/335907443/
# Requesting https://waarnemingen.be/observation/335849554/
# Requesting https://waarnemingen.be/observation/335848552/
# Requesting https://waarnemingen.be/observation/335827393/
# Requesting https://waarnemingen.be/observation/335825237/
# Requesting https://waarnemingen.be/observation/337079067/
# Requesting https://waarnemingen.be/observation/335904223/
# Requesting https://waarnemingen.be/observation/335827607/
# Requesting https://waarnemingen.be/observation/335821224/
# Requesting https://waarnemingen.be/observation/335839052/
# Requesting https://waarnemingen.be/observation/335821892/
# Requesting https://waarnemingen.be/observation/335836827/
# Requesting https://waarnemingen.be/observation/335815571/
# Requesting https://waarnemingen.be/observation/335928760/
# Requesting https://waarnemingen.be/observation/335823684/
# Requesting https://waarnemingen.be/observation/335837711/
# Requesting https://waarnemingen.be/observation/335823127/
# Requesting https://waarnemingen.be/observation/335813268/
# Requesting https://waarnemingen.be/observation/335812429/
# Requesting https://waarnemingen.be/observation/335829040/
# Requesting https://waarnemingen.be/observation/336664393/
# Requesting https://waarnemingen.be/observation/335829844/
# Requesting https://waarnemingen.be/observation/335806123/
# Requesting https://waarnemingen.be/observation/335805196/
# Requesting https://waarnemingen.be/observation/335805670/
# Requesting https://waarnemingen.be/observation/335804985/
# Requesting https://waarnemingen.be/observation/335804998/
# Requesting https://waarnemingen.be/observation/335806488/
# Requesting https://waarnemingen.be/observation/335805118/
# Requesting https://waarnemingen.be/observation/335805133/
# Requesting https://waarnemingen.be/observation/335806159/
# Requesting https://waarnemingen.be/observation/335801744/
# Requesting https://waarnemingen.be/observation/335810984/
# Requesting https://waarnemingen.be/observation/335801055/
# Requesting https://waarnemingen.be/observation/335801751/
# Requesting https://waarnemingen.be/observation/335801754/
# Requesting https://waarnemingen.be/observation/335801448/
# Requesting https://waarnemingen.be/observation/335798911/
# Requesting https://waarnemingen.be/observation/335801467/
# Requesting https://waarnemingen.be/observation/335798687/
# Requesting https://waarnemingen.be/observation/335803111/
# Requesting https://waarnemingen.be/observation/335798444/
# Requesting https://waarnemingen.be/observation/335839933/
# Requesting https://waarnemingen.be/observation/335806615/
# Requesting https://waarnemingen.be/observation/335798481/
# Requesting https://waarnemingen.be/observation/335806102/
# Requesting https://waarnemingen.be/observation/335799833/
# Requesting https://waarnemingen.be/observation/336017364/
# Requesting https://waarnemingen.be/observation/335815294/
# Requesting https://waarnemingen.be/observation/335885164/
# Requesting https://waarnemingen.be/observation/336718846/
# Requesting https://waarnemingen.be/observation/336446917/
# Requesting https://waarnemingen.be/observation/335856079/
# Requesting https://waarnemingen.be/observation/335854800/
# Requesting https://waarnemingen.be/observation/335852372/
# Requesting https://waarnemingen.be/observation/335835434/
# Requesting https://waarnemingen.be/observation/335821057/
# Requesting https://waarnemingen.be/observation/335814548/
# Requesting https://waarnemingen.be/observation/335794654/
# Requesting https://waarnemingen.be/observation/335825117/
# Requesting https://waarnemingen.be/observation/335773189/
# Requesting https://waarnemingen.be/observation/335803163/
# Requesting https://waarnemingen.be/observation/335803617/
# Requesting https://waarnemingen.be/observation/335771405/
# Requesting https://waarnemingen.be/observation/335775170/
# Requesting https://waarnemingen.be/observation/335749480/
# Requesting https://waarnemingen.be/observation/335749226/
# Requesting https://waarnemingen.be/observation/336424425/
# Requesting https://waarnemingen.be/observation/335749266/
# Requesting https://waarnemingen.be/observation/335749316/
# Requesting https://waarnemingen.be/observation/335749448/
# Requesting https://waarnemingen.be/observation/335749486/
# Requesting https://waarnemingen.be/observation/335749545/
# Requesting https://waarnemingen.be/observation/335768460/
# Requesting https://waarnemingen.be/observation/335749777/
# Requesting https://waarnemingen.be/observation/335741155/
# Requesting https://waarnemingen.be/observation/335750546/
# Requesting https://waarnemingen.be/observation/335751106/
# Requesting https://waarnemingen.be/observation/335751218/
# Requesting https://waarnemingen.be/observation/335751224/
# Requesting https://waarnemingen.be/observation/335802133/
# Requesting https://waarnemingen.be/observation/335740269/
# Requesting https://waarnemingen.be/observation/335792814/
# Requesting https://waarnemingen.be/observation/335792680/
# Requesting https://waarnemingen.be/observation/335792675/
# Requesting https://waarnemingen.be/observation/335715300/
# Requesting https://waarnemingen.be/observation/335715307/
# Requesting https://waarnemingen.be/observation/335720518/
# Requesting https://waarnemingen.be/observation/335707205/
# Requesting https://waarnemingen.be/observation/335703934/
# Requesting https://waarnemingen.be/observation/336690242/
# Requesting https://waarnemingen.be/observation/335737284/
# Requesting https://waarnemingen.be/observation/335728840/
# Requesting https://waarnemingen.be/observation/335694607/
# Requesting https://waarnemingen.be/observation/335790131/
# Requesting https://waarnemingen.be/observation/335715908/
# Requesting https://waarnemingen.be/observation/335694647/
# Requesting https://waarnemingen.be/observation/335694660/
# Requesting https://waarnemingen.be/observation/335698871/
# Requesting https://waarnemingen.be/observation/335694665/
# Requesting https://waarnemingen.be/observation/335715897/
# Requesting https://waarnemingen.be/observation/335715894/
# Requesting https://waarnemingen.be/observation/335694310/
# Requesting https://waarnemingen.be/observation/335692376/
# Requesting https://waarnemingen.be/observation/335715869/
# Requesting https://waarnemingen.be/observation/335715867/
# Requesting https://waarnemingen.be/observation/335715866/
# Requesting https://waarnemingen.be/observation/335694725/
# Requesting https://waarnemingen.be/observation/335694742/
# Requesting https://waarnemingen.be/observation/335715849/
# Requesting https://waarnemingen.be/observation/335694759/
# Requesting https://waarnemingen.be/observation/335807285/
# Requesting https://waarnemingen.be/observation/335690473/
# Requesting https://waarnemingen.be/observation/335694789/
# Requesting https://waarnemingen.be/observation/335694814/
# Requesting https://waarnemingen.be/observation/335690390/
# Requesting https://waarnemingen.be/observation/335690752/
# Requesting https://waarnemingen.be/observation/335694097/
# Requesting https://waarnemingen.be/observation/335694851/
# Requesting https://waarnemingen.be/observation/335690060/
# Requesting https://waarnemingen.be/observation/335694859/
# Requesting https://waarnemingen.be/observation/335694126/
# Requesting https://waarnemingen.be/observation/335694867/
# Requesting https://waarnemingen.be/observation/335694892/
# Requesting https://waarnemingen.be/observation/335694891/
# Requesting https://waarnemingen.be/observation/335694899/
# Requesting https://waarnemingen.be/observation/335694918/
# Requesting https://waarnemingen.be/observation/335689585/
# Requesting https://waarnemingen.be/observation/336718826/
# Requesting https://waarnemingen.be/observation/336252447/
# Requesting https://waarnemingen.be/observation/335728387/
# Requesting https://waarnemingen.be/observation/335728254/
# Requesting https://waarnemingen.be/observation/335604490/
# Requesting https://waarnemingen.be/observation/335607562/
# Requesting https://waarnemingen.be/observation/335595563/
# Requesting https://waarnemingen.be/observation/335778140/
# Requesting https://waarnemingen.be/observation/335589784/
# Requesting https://waarnemingen.be/observation/335589536/
# Requesting https://waarnemingen.be/observation/335597849/
# Requesting https://waarnemingen.be/observation/335587829/
# Requesting https://waarnemingen.be/observation/335601506/
# Requesting https://waarnemingen.be/observation/335585304/
# Requesting https://waarnemingen.be/observation/335583846/
# Requesting https://waarnemingen.be/observation/335583047/
# Requesting https://waarnemingen.be/observation/335583001/
# Requesting https://waarnemingen.be/observation/335610796/
# Requesting https://waarnemingen.be/observation/337079043/
# Requesting https://waarnemingen.be/observation/336349039/
# Requesting https://waarnemingen.be/observation/335979573/
# Requesting https://waarnemingen.be/observation/335577629/
# Requesting https://waarnemingen.be/observation/335588590/
# Requesting https://waarnemingen.be/observation/336349232/
# Requesting https://waarnemingen.be/observation/336718811/
# Requesting https://waarnemingen.be/observation/336252082/
# Requesting https://waarnemingen.be/observation/335726722/
# Requesting https://waarnemingen.be/observation/335614037/
# Requesting https://waarnemingen.be/observation/335607548/
# Requesting https://waarnemingen.be/observation/335584574/
# Requesting https://waarnemingen.be/observation/335577790/
# Requesting https://waarnemingen.be/observation/335554284/
# Requesting https://waarnemingen.be/observation/335545747/
# Requesting https://waarnemingen.be/observation/335571457/
# Requesting https://waarnemingen.be/observation/335596961/
# Requesting https://waarnemingen.be/observation/335552737/
# Requesting https://waarnemingen.be/observation/335571653/
# Requesting https://waarnemingen.be/observation/335571472/
# Requesting https://waarnemingen.be/observation/335576187/
# Requesting https://waarnemingen.be/observation/335542684/
# Requesting https://waarnemingen.be/observation/335542690/
# Requesting https://waarnemingen.be/observation/336042715/
# Requesting https://waarnemingen.be/observation/335532310/
# Requesting https://waarnemingen.be/observation/335532398/
# Requesting https://waarnemingen.be/observation/336042768/
# Requesting https://waarnemingen.be/observation/335537545/
# Requesting https://waarnemingen.be/observation/335528881/
# Requesting https://waarnemingen.be/observation/335532455/
# Requesting https://waarnemingen.be/observation/335531790/
# Requesting https://waarnemingen.be/observation/335571484/
# Requesting https://waarnemingen.be/observation/335534901/
# Requesting https://waarnemingen.be/observation/335526078/
# Requesting https://waarnemingen.be/observation/335534908/
# Requesting https://waarnemingen.be/observation/335528652/
# Requesting https://waarnemingen.be/observation/335558777/
# Requesting https://waarnemingen.be/observation/335532843/
# Requesting https://waarnemingen.be/observation/335532888/
# Requesting https://waarnemingen.be/observation/336718797/
# Requesting https://waarnemingen.be/observation/335556059/
# Requesting https://waarnemingen.be/observation/335543185/
# Requesting https://waarnemingen.be/observation/335525846/
# Requesting https://waarnemingen.be/observation/335525693/
# Requesting https://waarnemingen.be/observation/335524555/
# Requesting https://waarnemingen.be/observation/335573045/
# Requesting https://waarnemingen.be/observation/335502018/
# Requesting https://waarnemingen.be/observation/335498938/
# Requesting https://waarnemingen.be/observation/335507555/
# Requesting https://waarnemingen.be/observation/336086688/
# Requesting https://waarnemingen.be/observation/336086677/
# Requesting https://waarnemingen.be/observation/336086673/
# Requesting https://waarnemingen.be/observation/335492722/
# Requesting https://waarnemingen.be/observation/335492629/
# Requesting https://waarnemingen.be/observation/335492205/
# Requesting https://waarnemingen.be/observation/335500515/
# Requesting https://waarnemingen.be/observation/335524753/
# Requesting https://waarnemingen.be/observation/335490855/
# Requesting https://waarnemingen.be/observation/336991725/
# Requesting https://waarnemingen.be/observation/335515947/
# Requesting https://waarnemingen.be/observation/335480876/
# Requesting https://waarnemingen.be/observation/335480940/
# Requesting https://waarnemingen.be/observation/336189457/
# Requesting https://waarnemingen.be/observation/335496973/
# Requesting https://waarnemingen.be/observation/335485979/
# Requesting https://waarnemingen.be/observation/335477161/
# Requesting https://waarnemingen.be/observation/335481030/
# Requesting https://waarnemingen.be/observation/335480268/
# Requesting https://waarnemingen.be/observation/335481074/
# Requesting https://waarnemingen.be/observation/335480440/
# Requesting https://waarnemingen.be/observation/335518947/
# Requesting https://waarnemingen.be/observation/335480448/
# Requesting https://waarnemingen.be/observation/335481197/
# Requesting https://waarnemingen.be/observation/335498059/
# Requesting https://waarnemingen.be/observation/335481239/
# Requesting https://waarnemingen.be/observation/335478075/
# Requesting https://waarnemingen.be/observation/335481316/
# Requesting https://waarnemingen.be/observation/335484295/
# Requesting https://waarnemingen.be/observation/335481364/
# Requesting https://waarnemingen.be/observation/335486878/
# Requesting https://waarnemingen.be/observation/335481417/
# Requesting https://waarnemingen.be/observation/335481463/
# Requesting https://waarnemingen.be/observation/335481468/
# Requesting https://waarnemingen.be/observation/335474658/
# Requesting https://waarnemingen.be/observation/335514849/
# Requesting https://waarnemingen.be/observation/335514235/
# Requesting https://waarnemingen.be/observation/335514196/
# Requesting https://waarnemingen.be/observation/335506548/
# Requesting https://waarnemingen.be/observation/335513835/
# Requesting https://waarnemingen.be/observation/335513822/
# Requesting https://waarnemingen.be/observation/335464049/
# Requesting https://waarnemingen.be/observation/335510382/
# Requesting https://waarnemingen.be/observation/335463392/
# Requesting https://waarnemingen.be/observation/335463426/
# Requesting https://waarnemingen.be/observation/335463447/
# Requesting https://waarnemingen.be/observation/335463524/
# Requesting https://waarnemingen.be/observation/335463531/
# Requesting https://waarnemingen.be/observation/335469324/
# Requesting https://waarnemingen.be/observation/335468822/
# Requesting https://waarnemingen.be/observation/335458412/
# Requesting https://waarnemingen.be/observation/335477025/
# Requesting https://waarnemingen.be/observation/335453365/
# Requesting https://waarnemingen.be/observation/335452347/
# Requesting https://waarnemingen.be/observation/336718782/
# Requesting https://waarnemingen.be/observation/335470845/
# Requesting https://waarnemingen.be/observation/335470844/
# Requesting https://waarnemingen.be/observation/335470736/
# Requesting https://waarnemingen.be/observation/335470454/
# Requesting https://waarnemingen.be/observation/335470423/
# Requesting https://waarnemingen.be/observation/335470272/
# Requesting https://waarnemingen.be/observation/335470225/
# Requesting https://waarnemingen.be/observation/335465901/
# Requesting https://waarnemingen.be/observation/335432063/
# Requesting https://waarnemingen.be/observation/335449004/
# Requesting https://waarnemingen.be/observation/335431521/
# Requesting https://waarnemingen.be/observation/335433485/
# Requesting https://waarnemingen.be/observation/335438749/
# Requesting https://waarnemingen.be/observation/335435067/
# Requesting https://waarnemingen.be/observation/335432584/
# Requesting https://waarnemingen.be/observation/335431270/
# Requesting https://waarnemingen.be/observation/335417252/
# Requesting https://waarnemingen.be/observation/335417328/
# Requesting https://waarnemingen.be/observation/335450881/
# Requesting https://waarnemingen.be/observation/335417410/
# Requesting https://waarnemingen.be/observation/335417417/
# Requesting https://waarnemingen.be/observation/335421150/
# Requesting https://waarnemingen.be/observation/335417436/
# Requesting https://waarnemingen.be/observation/335443402/
# Requesting https://waarnemingen.be/observation/335417468/
# Requesting https://waarnemingen.be/observation/335414103/
# Requesting https://waarnemingen.be/observation/335413919/
# Requesting https://waarnemingen.be/observation/335417504/
# Requesting https://waarnemingen.be/observation/335417508/
# Requesting https://waarnemingen.be/observation/336718771/
# Requesting https://waarnemingen.be/observation/335518314/
# Requesting https://waarnemingen.be/observation/335518137/
# Requesting https://waarnemingen.be/observation/335517657/
# Requesting https://waarnemingen.be/observation/335517644/
# Requesting https://waarnemingen.be/observation/335517578/
# Requesting https://waarnemingen.be/observation/335516485/
# Requesting https://waarnemingen.be/observation/335514746/
# Requesting https://waarnemingen.be/observation/335435502/
# Requesting https://waarnemingen.be/observation/335408334/
# Requesting https://waarnemingen.be/observation/335386488/
# Requesting https://waarnemingen.be/observation/335392958/
# Requesting https://waarnemingen.be/observation/335407612/
# Requesting https://waarnemingen.be/observation/335390813/
# Requesting https://waarnemingen.be/observation/335392989/
# Requesting https://waarnemingen.be/observation/335388419/
# Requesting https://waarnemingen.be/observation/335420220/
# Requesting https://waarnemingen.be/observation/335417487/
# Requesting https://waarnemingen.be/observation/335379750/
# Requesting https://waarnemingen.be/observation/335377133/
# Requesting https://waarnemingen.be/observation/335377290/
# Requesting https://waarnemingen.be/observation/335376658/
# Requesting https://waarnemingen.be/observation/335400709/
# Requesting https://waarnemingen.be/observation/335376690/
# Requesting https://waarnemingen.be/observation/335409747/
# Requesting https://waarnemingen.be/observation/335376701/
# Requesting https://waarnemingen.be/observation/335400715/
# Requesting https://waarnemingen.be/observation/335376708/
# Requesting https://waarnemingen.be/observation/335376664/
# Requesting https://waarnemingen.be/observation/335449281/
# Requesting https://waarnemingen.be/observation/335376712/
# Requesting https://waarnemingen.be/observation/335373803/
# Requesting https://waarnemingen.be/observation/335373508/
# Requesting https://waarnemingen.be/observation/335393107/
# Requesting https://waarnemingen.be/observation/335378718/
# Requesting https://waarnemingen.be/observation/335376941/
# Requesting https://waarnemingen.be/observation/335480396/
# Requesting https://waarnemingen.be/observation/335384191/
# Requesting https://waarnemingen.be/observation/335401434/
# Requesting https://waarnemingen.be/observation/335381574/
# Requesting https://waarnemingen.be/observation/335399014/
# Requesting https://waarnemingen.be/observation/335377056/
# Requesting https://waarnemingen.be/observation/335369850/
# Requesting https://waarnemingen.be/observation/335369774/
# Requesting https://waarnemingen.be/observation/335369860/
# Requesting https://waarnemingen.be/observation/335377073/
# Requesting https://waarnemingen.be/observation/335377083/
# Requesting https://waarnemingen.be/observation/335377095/
# Requesting https://waarnemingen.be/observation/335377104/
# Requesting https://waarnemingen.be/observation/335369882/
# Requesting https://waarnemingen.be/observation/335368649/
# Requesting https://waarnemingen.be/observation/336718761/
# Requesting https://waarnemingen.be/observation/335725775/
# Requesting https://waarnemingen.be/observation/335407406/
# Requesting https://waarnemingen.be/observation/335407291/
# Requesting https://waarnemingen.be/observation/335355431/
# Requesting https://waarnemingen.be/observation/335350671/
# Requesting https://waarnemingen.be/observation/335352504/
# Requesting https://waarnemingen.be/observation/335351873/
# Requesting https://waarnemingen.be/observation/336042806/
# Requesting https://waarnemingen.be/observation/335347346/
# Requesting https://waarnemingen.be/observation/335338251/
# Requesting https://waarnemingen.be/observation/335392106/
# Requesting https://waarnemingen.be/observation/336042823/
# Requesting https://waarnemingen.be/observation/335333559/
# Requesting https://waarnemingen.be/observation/335333664/
# Requesting https://waarnemingen.be/observation/335333738/
# Requesting https://waarnemingen.be/observation/335333780/
# Requesting https://waarnemingen.be/observation/335352436/
# Requesting https://waarnemingen.be/observation/335333872/
# Requesting https://waarnemingen.be/observation/335328821/
# Requesting https://waarnemingen.be/observation/335333885/
# Requesting https://waarnemingen.be/observation/335333910/
# Requesting https://waarnemingen.be/observation/335328976/
# Requesting https://waarnemingen.be/observation/335333976/
# Requesting https://waarnemingen.be/observation/335352651/
# Requesting https://waarnemingen.be/observation/335334026/
# Requesting https://waarnemingen.be/observation/335576408/
# Requesting https://waarnemingen.be/observation/335334104/
# Requesting https://waarnemingen.be/observation/335334107/
# Requesting https://waarnemingen.be/observation/335334172/
# Requesting https://waarnemingen.be/observation/335352638/
# Requesting https://waarnemingen.be/observation/336718747/
# Requesting https://waarnemingen.be/observation/335409160/
# Requesting https://waarnemingen.be/observation/335407668/
# Requesting https://waarnemingen.be/observation/335327019/
# Requesting https://waarnemingen.be/observation/335238564/
# Requesting https://waarnemingen.be/observation/335230615/
# Requesting https://waarnemingen.be/observation/335431363/
# Requesting https://waarnemingen.be/observation/335230988/
# Requesting https://waarnemingen.be/observation/335231054/
# Requesting https://waarnemingen.be/observation/335231062/
# Requesting https://waarnemingen.be/observation/335226163/
# Requesting https://waarnemingen.be/observation/335231092/
# Requesting https://waarnemingen.be/observation/335233392/
# Requesting https://waarnemingen.be/observation/335231098/
# Requesting https://waarnemingen.be/observation/335222780/
# Requesting https://waarnemingen.be/observation/335220841/
# Requesting https://waarnemingen.be/observation/335262940/
# Requesting https://waarnemingen.be/observation/335221677/
# Requesting https://waarnemingen.be/observation/335231567/
# Requesting https://waarnemingen.be/observation/335242233/
# Requesting https://waarnemingen.be/observation/335214592/
# Requesting https://waarnemingen.be/observation/335219315/
# Requesting https://waarnemingen.be/observation/335215579/
# Requesting https://waarnemingen.be/observation/336086523/
# Requesting https://waarnemingen.be/observation/336086515/
# Requesting https://waarnemingen.be/observation/335222918/
# Requesting https://waarnemingen.be/observation/335213250/
# Requesting https://waarnemingen.be/observation/335241403/
# Requesting https://waarnemingen.be/observation/335213264/
# Requesting https://waarnemingen.be/observation/335253573/
# Requesting https://waarnemingen.be/observation/335240411/
# Requesting https://waarnemingen.be/observation/335224308/
# Requesting https://waarnemingen.be/observation/335218450/
# Requesting https://waarnemingen.be/observation/335222882/
# Requesting https://waarnemingen.be/observation/335213375/
# Requesting https://waarnemingen.be/observation/335213380/
# Requesting https://waarnemingen.be/observation/335222887/
# Requesting https://waarnemingen.be/observation/335206856/
# Requesting https://waarnemingen.be/observation/335208936/
# Requesting https://waarnemingen.be/observation/335208653/
# Requesting https://waarnemingen.be/observation/335213419/
# Requesting https://waarnemingen.be/observation/335242546/
# Requesting https://waarnemingen.be/observation/335213436/
# Requesting https://waarnemingen.be/observation/335207159/
# Requesting https://waarnemingen.be/observation/337079038/
# Requesting https://waarnemingen.be/observation/335212814/
# Requesting https://waarnemingen.be/observation/335214310/
# Requesting https://waarnemingen.be/observation/335213474/
# Requesting https://waarnemingen.be/observation/335289141/
# Requesting https://waarnemingen.be/observation/335222896/
# Requesting https://waarnemingen.be/observation/335212821/
# Requesting https://waarnemingen.be/observation/335225485/
# Requesting https://waarnemingen.be/observation/335215659/
# Requesting https://waarnemingen.be/observation/335213507/
# Requesting https://waarnemingen.be/observation/335209899/
# Requesting https://waarnemingen.be/observation/337079032/
# Requesting https://waarnemingen.be/observation/335800271/
# Requesting https://waarnemingen.be/observation/335204163/
# Requesting https://waarnemingen.be/observation/335204101/
# Requesting https://waarnemingen.be/observation/335213633/
# Requesting https://waarnemingen.be/observation/335240300/
# Requesting https://waarnemingen.be/observation/335203615/
# Requesting https://waarnemingen.be/observation/335203595/
# Requesting https://waarnemingen.be/observation/335213669/
# Requesting https://waarnemingen.be/observation/335212845/
# Requesting https://waarnemingen.be/observation/335213694/
# Requesting https://waarnemingen.be/observation/335205293/
# Requesting https://waarnemingen.be/observation/335211146/
# Requesting https://waarnemingen.be/observation/335206350/
# Requesting https://waarnemingen.be/observation/335213713/
# Requesting https://waarnemingen.be/observation/335213726/
# Requesting https://waarnemingen.be/observation/335202770/
# Requesting https://waarnemingen.be/observation/335213747/
# Requesting https://waarnemingen.be/observation/335211158/
# Requesting https://waarnemingen.be/observation/336113936/
# Requesting https://waarnemingen.be/observation/336113930/
# Requesting https://waarnemingen.be/observation/336718740/
