# %% [markdown]
# # Observations

# %%
import pandas as pd

# set the max columns to none
pd.set_option('display.max_columns', None)
# set the max columns to none
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Input species id for transformation

# %%
species_id = 116

# %%
species = { 
        70 : {'afkorting' : 'hp', 'soort' : 'halsbandparkiet'}, 
        116 : {'afkorting' : 'bk', 'soort' : 'boomklever'}
        }

# %% [markdown]
# ## Load clean data

# %%
# Load the data
observations = f'../2_cleaning/clean_data/observations_{species_id}_clean.parquet'
df_observations = pd.read_parquet(observations, engine="pyarrow")

# %% [markdown]
# ## Transform data

# %%
df_observations.describe(include='all')
# Out:
#         species_id     species_name species_name_scientific  \
# count      96551.0            96551                   96551
# unique         NaN                1                       1
# top            NaN  Halsbandparkiet      Psittacula krameri
# freq           NaN            96551                   96551
# mean         116.0              NaN                     NaN
# min          116.0              NaN                     NaN
# 25%          116.0              NaN                     NaN
# 50%          116.0              NaN                     NaN
# 75%          116.0              NaN                     NaN
# max          116.0              NaN                     NaN
# std            0.0              NaN                     NaN
#
#                                   validation  gps_coordinates source  \
# count                                  96551            96551  92386
# unique                                     5            63817     26
# top     Goedgekeurd (automatische validatie)  51.0509, 4.3699   Site
# freq                                   57468              961  46233
# mean                                     NaN              NaN    NaN
# min                                      NaN              NaN    NaN
# 25%                                      NaN              NaN    NaN
# 50%                                      NaN              NaN    NaN
# 75%                                      NaN              NaN    NaN
# max                                      NaN              NaN    NaN
# std                                      NaN              NaN    NaN
#
#                                  date        amount life_stage     activity  \
# count                           96551  96551.000000      96180        96180
# unique                            NaN           NaN         19           44
# top                               NaN           NaN   onbekend  ter plaatse
# freq                              NaN           NaN      87789        56128
# mean    2019-07-29 17:06:33.479093760      4.905760        NaN          NaN
# min               1971-10-03 00:00:00      1.000000        NaN          NaN
# 25%               2017-08-14 00:00:00      1.000000        NaN          NaN
# 50%               2020-08-19 00:00:00      2.000000        NaN          NaN
# 75%               2022-12-03 00:00:00      3.000000        NaN          NaN
# max               2024-12-31 00:00:00    983.000000        NaN          NaN
# std                               NaN     25.303922        NaN          NaN
#
#           location_id         location   observer_id        observer_name  \
# count    95694.000000            95694  9.639400e+04                96394
# unique            NaN             3075           NaN                 6008
# top               NaN  Willebroek (AN)           NaN  Wim Van den Bossche
# freq              NaN             7041           NaN                14471
# mean     60560.293874              NaN  8.826089e+04                  NaN
# min      23088.000000              NaN  1.850000e+02                  NaN
# 25%      24033.000000              NaN  4.042000e+04                  NaN
# 50%      29069.000000              NaN  4.645600e+04                  NaN
# 75%      41806.000000              NaN  9.407500e+04                  NaN
# max     724090.000000              NaN  1.058369e+06                  NaN
# std     101612.798323              NaN  1.127571e+05                  NaN
#
#        counting_method    method latitude longitude    accuracy_m
# count            96551     96551    96551     96551  90266.000000
# unique               7        15     8078     11229           NaN
# top           onbekend  onbekend  51.0509    4.3699           NaN
# freq             79123     60631     1759      1202           NaN
# mean               NaN       NaN      NaN       NaN     41.937108
# min                NaN       NaN      NaN       NaN      1.000000
# 25%                NaN       NaN      NaN       NaN     10.000000
# 50%                NaN       NaN      NaN       NaN     10.000000
# 75%                NaN       NaN      NaN       NaN     25.000000
# max                NaN       NaN      NaN       NaN   1407.000000
# std                NaN       NaN      NaN       NaN    111.373513

# %%
df_observations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96551 entries, 336301369 to 233392391
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   species_id               96551 non-null  int64
#  1   species_name             96551 non-null  object
#  2   species_name_scientific  96551 non-null  object
#  3   validation               96551 non-null  object
#  4   gps_coordinates          96551 non-null  object
#  5   source                   92386 non-null  object
#  6   date                     96551 non-null  datetime64[ns]
#  7   amount                   96551 non-null  int64
#  8   life_stage               96180 non-null  object
#  9   activity                 96180 non-null  object
#  10  location_id              95694 non-null  float64
#  11  location                 95694 non-null  object
#  12  observer_id              96394 non-null  float64
#  13  observer_name            96394 non-null  object
#  14  counting_method          96551 non-null  object
#  15  method                   96551 non-null  object
#  16  latitude                 96551 non-null  object
#  17  longitude                96551 non-null  object
#  18  accuracy_m               90266 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(13)
# memory usage: 14.7+ MB

# %%
df_observations.head(2)
# Out:
#                 species_id     species_name species_name_scientific  \
# observation_id
# 336301369              116  Halsbandparkiet      Psittacula krameri
# 336233189              116  Halsbandparkiet      Psittacula krameri
#
#                                           validation  gps_coordinates  \
# observation_id
# 336301369       Goedgekeurd (automatische validatie)  50.8585, 4.6717
# 336233189       Goedgekeurd (automatische validatie)  50.8044, 4.6010
#
#                   source       date  amount life_stage     activity  \
# observation_id
# 336301369           iObs 2024-12-31       1   onbekend  ter plaatse
# 336233189       Showcase 2024-12-31       1   onbekend  ter plaatse
#
#                 location_id                                   location  \
# observation_id
# 336301369           30919.0  Heverlee - Egenhoven - Egenhoven Bos (VB)
# 336233189           30976.0                 Loonbeek - Korenheide (VB)
#
#                 observer_id   observer_name counting_method    method  \
# observation_id
# 336301369           40236.0  Frederik Fluyt        onbekend  onbekend
# 336233189            3528.0    Externe bron            geen  onbekend
#
#                latitude longitude  accuracy_m
# observation_id
# 336301369       50.8585    4.6717        33.0
# 336233189       50.8044    4.6010        30.0

# %%
df_observations_gold = df_observations[['species_id', 'species_name', 'date', 'observer_id', 'latitude', 'longitude']]

# %% [markdown]
# ## Write result to parquet-file in "gold" folder

# %%
df_observations_gold.to_parquet(f'./gold/observations_{species[species_id]['afkorting']}.parquet', engine="pyarrow")
