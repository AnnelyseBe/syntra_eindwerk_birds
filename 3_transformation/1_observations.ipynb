# %% [markdown]
# # Observations

# %%
import pandas as pd

# set the max columns to none
pd.set_option('display.max_columns', None)
# set the max columns to none
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Input species id for transformation

# %%
species_id = 116

# %%
species = { 
        116 : {'afkorting' : 'hp', 'soort' : 'halsbandparkiet'}, 
        70 : {'afkorting' : 'bk', 'soort' : 'boomklever'}
        }

# %% [markdown]
# ## Load clean data

# %%
# Load the data
observations = f'../2_cleaning/clean_data/observations_{species_id}_clean.parquet'
df_observations = pd.read_parquet(observations, engine="pyarrow")

# %% [markdown]
# ## Transform data

# %%
df_observations.reset_index(drop=False, inplace=True)

# %%
df_observations.describe(include='all')
# Out:
#         observation_id  species_id     species_name species_name_scientific  \
# count     9.655100e+04     96551.0            96551                   96551
# unique             NaN         NaN                1                       1
# top                NaN         NaN  Halsbandparkiet      Psittacula krameri
# freq               NaN         NaN            96551                   96551
# mean      1.969949e+08       116.0              NaN                     NaN
# min       4.000045e+07       116.0              NaN                     NaN
# 25%       1.440421e+08       116.0              NaN                     NaN
# 50%       1.998252e+08       116.0              NaN                     NaN
# 75%       2.607655e+08       116.0              NaN                     NaN
# max       3.370792e+08       116.0              NaN                     NaN
# std       7.686714e+07         0.0              NaN                     NaN
#
# ...

# %%
df_observations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96551 entries, 0 to 96550
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   observation_id           96551 non-null  int64
#  1   species_id               96551 non-null  int64
#  2   species_name             96551 non-null  object
#  3   species_name_scientific  96551 non-null  object
#  4   validation               96551 non-null  object
#  5   gps_coordinates          96551 non-null  object
#  6   source                   92386 non-null  object
#  7   date                     96551 non-null  datetime64[ns]
#  8   amount                   96551 non-null  int64
#  9   life_stage               96180 non-null  object
#  10  activity                 96180 non-null  object
#  11  location_id              95694 non-null  float64
#  12  location                 95694 non-null  object
#  13  observer_id              96394 non-null  float64
# ...

# %%
df_observations.head(2)
# Out:
#    observation_id  species_id     species_name species_name_scientific  \
# 0       336301369         116  Halsbandparkiet      Psittacula krameri
# 1       336233189         116  Halsbandparkiet      Psittacula krameri
#
#                              validation  gps_coordinates    source       date  \
# 0  Goedgekeurd (automatische validatie)  50.8585, 4.6717      iObs 2024-12-31
# 1  Goedgekeurd (automatische validatie)  50.8044, 4.6010  Showcase 2024-12-31
#
#    amount life_stage     activity  location_id  \
# 0       1   onbekend  ter plaatse      30919.0
# 1       1   onbekend  ter plaatse      30976.0
#
#                                     location  observer_id   observer_name  \
# 0  Heverlee - Egenhoven - Egenhoven Bos (VB)      40236.0  Frederik Fluyt
# 1                 Loonbeek - Korenheide (VB)       3528.0    Externe bron
#
#   counting_method    method latitude longitude  accuracy_m
# 0        onbekend  onbekend  50.8585    4.6717        33.0
# ...

# %%
df_observations_gold = df_observations[['species_id', 'species_name', 'date', 'observer_id', 'latitude', 'longitude', 'location_id', 'observation_id','source']]

# %%
df_observations_gold[df_observations_gold['date'].dt.year == 2011].head(2)
# Out:
#        species_id     species_name       date  observer_id latitude longitude  \
# 90491         116  Halsbandparkiet 2011-12-31      53943.0  50.8328    4.2099
# 90492         116  Halsbandparkiet 2011-12-31      40698.0  50.8076    4.5745
#
#        location_id  observation_id source
# 90491      23242.0        62527715   None
# 90492      28479.0        62341191   None

# %% [markdown]
# ## Write result to parquet-file in "gold" folder

# %%
df_observations_gold.to_parquet(f'./gold/observations_{species[species_id]['afkorting']}.parquet', index= True, engine="pyarrow")
