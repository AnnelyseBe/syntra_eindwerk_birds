# %%
import pandas as pd
import os

# %%
os.getcwd()
# set the max columns to none
pd.set_option('display.max_columns', None)
# set the max columns to none
pd.set_option('display.max_rows', None)

# %%
# Replace 'data.txt' with your file path
big_file_verbatim = 'raw_data/verbatim.txt'

# Load the data
df_verbatim = pd.read_csv(big_file_verbatim, sep="\t", nrows=100)

df_verbatim.head()
# Out:
#        gbifID                                      accessRights  \
# 0  2259536899  http://www.natuurpunt.be/normen-voor-datagebruik
# 1  2259260808  http://www.natuurpunt.be/normen-voor-datagebruik
# 2  2259534507  http://www.natuurpunt.be/normen-voor-datagebruik
# 3  2262647663  http://www.natuurpunt.be/normen-voor-datagebruik
# 4  2263989008  http://www.natuurpunt.be/normen-voor-datagebruik
#
#    bibliographicCitation language  \
# 0                    NaN       en
# 1                    NaN       en
# 2                    NaN       en
# 3                    NaN       en
# 4                    NaN       en
#
#                                              license  modified  publisher  \
# 0  http://creativecommons.org/publicdomain/zero/1.0/       NaN        NaN
# 1  http://creativecommons.org/publicdomain/zero/1.0/       NaN        NaN
# 2  http://creativecommons.org/publicdomain/zero/1.0/       NaN        NaN
# ...

# %%
df_verbatim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 190 entries, gbifID to taxonRemarks
# dtypes: float64(148), int64(3), object(39)
# memory usage: 148.6+ KB

# %%
df_verbatim.describe()
# Out:
#              gbifID  bibliographicCitation  modified  publisher  \
# count  1.000000e+02                    0.0       0.0        0.0
# mean   2.258334e+09                    NaN       NaN        NaN
# std    3.329283e+06                    NaN       NaN        NaN
# min    2.252583e+09                    NaN       NaN        NaN
# 25%    2.255820e+09                    NaN       NaN        NaN
# 50%    2.257867e+09                    NaN       NaN        NaN
# 75%    2.261045e+09                    NaN       NaN        NaN
# max    2.264990e+09                    NaN       NaN        NaN
#
#        institutionID  collectionID  ownerInstitutionCode  dynamicProperties  \
# count            0.0           0.0                   0.0                0.0
# mean             NaN           NaN                   NaN                NaN
# std              NaN           NaN                   NaN                NaN
# min              NaN           NaN                   NaN                NaN
# ...

# %%
df_verbatim.isnull().sum()
# Out:
# gbifID                                   0
# accessRights                             0
# bibliographicCitation                  100
# language                                 0
# license                                  0
# modified                               100
# publisher                              100
# references                               0
# rightsHolder                             0
# type                                     0
# institutionID                          100
# collectionID                           100
# datasetID                                0
# institutionCode                          0
# collectionCode                           0
# datasetName                              0
# ownerInstitutionCode                   100
# basisOfRecord                            0
# informationWithheld                      0
# dataGeneralizations                      0
# dynamicProperties                      100
# occurrenceID                             0
# ...
