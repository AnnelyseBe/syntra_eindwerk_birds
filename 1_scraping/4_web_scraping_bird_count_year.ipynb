# %% [markdown]
# # Ophalen aantal vogeltellingen per jaar
#
# Vermits er jaar na jaar meer vogelwaarnemingen worden gelogged, is het belangrijk om de totale jaarlijkse vogelwaarnemingen ook op te halen, zodat we de groei van elke soort in kaart kunnen brengen tov het totaal aantal vogelwaarnemingen.

# %%
import bs4
import requests
import pandas as pd
from datetime import datetime
import time
import os
import re



# Base URL for scraping

base_url = 'https://waarnemingen.be/species/?species_group_id=1&filter_month=&filter_year={}&include_exotic_and_extinct=on&own_species=all+species' 

# Function to parse a single page
def parse_page(year, retries=10, backoff_factor=2):
    
    headers = {
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36",
        "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
        "accept-encoding":"gzip, deflate, br, zstd",
        "accept-language":"nl-BE,nl;q=0.9,en-BE;q=0.8,en;q=0.7,nl-NL;q=0.6,en-US;q=0.5",
        "connection":"keep-alive",
        "cookie":"csrftoken=3JbFPYJyRC9GxhkNoW4XzF1vbbG6Fbxe; sessionid=v132os9mxwltj3ol3plhmojrjch24m9o; fundraiser_dismissed=1; cookielaw_accepted=1",
        "host":"waarnemingen.be",
        "Referer": "https://www.google.com/",
        "sec-ch-ua":'"Not A(Brand";v="8", "Chromium";v="132", "Google Chrome";v="132"',
        "sec-ch-ua-mobile":"?0",
        "sec-ch-ua-platform":"Linux",
        "sec-fetch-dest":"document",
        "sec-fetch-mode":"navigate",
        "sec-fetch-site":"same-origin",
        "sec-fetch-user":"?1",
        "upgrade-insecure-requests":"1"
            }
    
    for attempt in range(retries):
        try:
            res = requests.get(base_url.format(year), headers=headers)
            res.raise_for_status()
            soup = bs4.BeautifulSoup(res.text, 'html.parser')
            
            year_stats = soup.select_one('.callout.callout-primary').getText(strip=True) if soup.select_one('.callout.callout-primary') else None,
            print(f'year stats: {year_stats}')
            
            # Regular expression to find "X waarnemingen van Y individuen"
            matches = re.search(r'([\d\.]+) waarnemingen van ([\d\.]+) individuen', str(year_stats))
            
            observation_count = matches[1]
            individu_count = matches[2]
            
            print(f'year observation_count: {observation_count}')
            print(f'year individu_count: {individu_count}')
            
            year_observations = {
                "year": year,
                "observation_count": int(observation_count.replace('.', '')),
                "individu_count": int(individu_count.replace('.', '')),
            }

            
            print(year_observations)
            return year_observations

            
        except requests.exceptions.HTTPError as e:
            print(f"HTTP error: {e} on attempt {attempt + 1}/{retries}")
            if attempt < retries - 1:
                time.sleep(backoff_factor * (2 ** attempt))
                continue
            else:
                raise e

def scrape(year_start = 1971, year_end = 2024):
    file_name = make_filename()
    year = year_start
    first_write = True if year_start == 1971 else False  # Add header only for the first page
    
    while (year <= year_end):
        print(f"Scraping year {year}")
        try:
            result = parse_page(year)
            
            # Convert observations to a DataFrame
            if result:
                df = pd.DataFrame([result])
                
                # Append locations to CSV
                df.to_csv(
                    file_name,
                    mode='a',  # Append mode
                    index=False,
                    header=first_write  # Write header only for the first write
                )
                first_write = False  # Ensure header is only written once
            
            time.sleep(5)  # Respectful delay between requests
            year += 1
        except Exception as e:
            print(f"An error occurred: {e}")
            break
    df = pd.read_csv(file_name)
    print(f"Scraped {len(df)} years, last scraped year: {year - 1}")
    os.rename(file_name, make_filename(year_start, year - 1))
    return df

def make_filename(year_start=None, year_end_incl=None):
    current_date = datetime.now().strftime('%Y-%m-%d')
    directory = 'scraped_data'
    
    # Controleer of de map bestaat, anders maak je die aan
    if not os.path.exists(directory):
        os.makedirs(directory)

    base_name = f'{directory}/observation_year_count_{current_date}'
    if year_start and year_end_incl:
        base_name = base_name + f'_year_{year_start}-{year_end_incl}'
    
    return base_name + '.csv'

#################################################################################################################

year_start = 2022
year_end = 2024

scrape() # Scrape all pages

print("Scraping of yearly count of observations and individues is complete. Data saved to .csv file")
# Out:
# Scraping year 1971
# year stats: ('2.242 waarnemingen van 34.987 individuen resulteerden in een lijst van207 soorten,4 verzamelsoorten,2 ondersoorten,1 forma.',)
# year observation_count: 2.242
# year individu_count: 34.987
# {'year': 1971, 'observation_count': 2242, 'individu_count': 34987}
# Scraping year 1972
# year stats: ('5.281 waarnemingen van 80.669 individuen resulteerden in een lijst van239 soorten,2 verzamelsoorten,5 ondersoorten.',)
# year observation_count: 5.281
# year individu_count: 80.669
# {'year': 1972, 'observation_count': 5281, 'individu_count': 80669}
# Scraping year 1973
# year stats: ('6.547 waarnemingen van 99.533 individuen resulteerden in een lijst van234 soorten,3 verzamelsoorten,7 ondersoorten.',)
# year observation_count: 6.547
# year individu_count: 99.533
# {'year': 1973, 'observation_count': 6547, 'individu_count': 99533}
# Scraping year 1974
# year stats: ('9.548 waarnemingen van 147.922 individuen resulteerden in een lijst van236 soorten,4 verzamelsoorten,9 ondersoorten.',)
# year observation_count: 9.548
# year individu_count: 147.922
# {'year': 1974, 'observation_count': 9548, 'individu_count': 147922}
# Scraping year 1975
# year stats: ('9.115 waarnemingen van 122.869 individuen resulteerden in een lijst van260 soorten,2 verzamelsoorten,14 ondersoorten,1 forma.',)
# year observation_count: 9.115
# year individu_count: 122.869
# {'year': 1975, 'observation_count': 9115, 'individu_count': 122869}
# Scraping year 1976
# year stats: ('7.035 waarnemingen van 94.571 individuen resulteerden in een lijst van253 soorten,3 verzamelsoorten,14 ondersoorten.',)
# year observation_count: 7.035
# year individu_count: 94.571
# {'year': 1976, 'observation_count': 7035, 'individu_count': 94571}
# Scraping year 1977
# year stats: ('7.394 waarnemingen van 203.219 individuen resulteerden in een lijst van253 soorten,3 verzamelsoorten,11 ondersoorten.',)
# year observation_count: 7.394
# year individu_count: 203.219
# {'year': 1977, 'observation_count': 7394, 'individu_count': 203219}
# Scraping year 1978
# year stats: ('11.301 waarnemingen van 253.846 individuen resulteerden in een lijst van267 soorten,14 verzamelsoorten,10 ondersoorten.',)
# year observation_count: 11.301
# year individu_count: 253.846
# {'year': 1978, 'observation_count': 11301, 'individu_count': 253846}
# Scraping year 1979
# year stats: ('15.202 waarnemingen van 404.617 individuen resulteerden in een lijst van273 soorten,1 hybride,13 verzamelsoorten,14 ondersoorten.',)
# year observation_count: 15.202
# year individu_count: 404.617
# {'year': 1979, 'observation_count': 15202, 'individu_count': 404617}
# Scraping year 1980
# year stats: ('23.498 waarnemingen van 544.527 individuen resulteerden in een lijst van284 soorten,1 hybride,21 verzamelsoorten,1 variant,16 ondersoorten,2 forma.',)
# year observation_count: 23.498
# year individu_count: 544.527
# {'year': 1980, 'observation_count': 23498, 'individu_count': 544527}
# Scraping year 1981
# year stats: ('34.244 waarnemingen van 939.880 individuen resulteerden in een lijst van283 soorten,1 hybride,23 verzamelsoorten,16 ondersoorten,2 forma.',)
# year observation_count: 34.244
# year individu_count: 939.880
# {'year': 1981, 'observation_count': 34244, 'individu_count': 939880}
# Scraping year 1982
# year stats: ('32.669 waarnemingen van 1.201.891 individuen resulteerden in een lijst van285 soorten,2 hybrides,16 verzamelsoorten,11 ondersoorten,3 forma.',)
# year observation_count: 32.669
# year individu_count: 1.201.891
# {'year': 1982, 'observation_count': 32669, 'individu_count': 1201891}
# Scraping year 1983
# year stats: ('34.838 waarnemingen van 911.578 individuen resulteerden in een lijst van286 soorten,1 hybride,23 verzamelsoorten,12 ondersoorten,3 forma.',)
# year observation_count: 34.838
# year individu_count: 911.578
# {'year': 1983, 'observation_count': 34838, 'individu_count': 911578}
# Scraping year 1984
# year stats: ('34.292 waarnemingen van 1.319.743 individuen resulteerden in een lijst van296 soorten,3 hybrides,20 verzamelsoorten,19 ondersoorten,1 forma.',)
# year observation_count: 34.292
# year individu_count: 1.319.743
# {'year': 1984, 'observation_count': 34292, 'individu_count': 1319743}
# Scraping year 1985
# year stats: ('39.579 waarnemingen van 1.232.770 individuen resulteerden in een lijst van301 soorten,2 hybrides,19 verzamelsoorten,1 variant,16 ondersoorten,3 forma.',)
# year observation_count: 39.579
# year individu_count: 1.232.770
# {'year': 1985, 'observation_count': 39579, 'individu_count': 1232770}
# Scraping year 1986
# year stats: ('42.956 waarnemingen van 1.038.206 individuen resulteerden in een lijst van308 soorten,4 hybrides,19 verzamelsoorten,17 ondersoorten,1 forma.',)
# year observation_count: 42.956
# year individu_count: 1.038.206
# {'year': 1986, 'observation_count': 42956, 'individu_count': 1038206}
# Scraping year 1987
# year stats: ('38.254 waarnemingen van 1.440.391 individuen resulteerden in een lijst van314 soorten,7 hybrides,18 verzamelsoorten,17 ondersoorten,3 forma.',)
# year observation_count: 38.254
# year individu_count: 1.440.391
# {'year': 1987, 'observation_count': 38254, 'individu_count': 1440391}
# Scraping year 1988
# year stats: ('42.587 waarnemingen van 1.336.016 individuen resulteerden in een lijst van324 soorten,9 hybrides,18 verzamelsoorten,1 variant,22 ondersoorten,2 forma.',)
# year observation_count: 42.587
# year individu_count: 1.336.016
# {'year': 1988, 'observation_count': 42587, 'individu_count': 1336016}
# Scraping year 1989
# year stats: ('49.273 waarnemingen van 1.435.515 individuen resulteerden in een lijst van336 soorten,6 hybrides,20 verzamelsoorten,1 variant,57 ondersoorten,2 forma.',)
# year observation_count: 49.273
# year individu_count: 1.435.515
# {'year': 1989, 'observation_count': 49273, 'individu_count': 1435515}
# Scraping year 1990
# year stats: ('55.037 waarnemingen van 1.592.230 individuen resulteerden in een lijst van326 soorten,6 hybrides,17 verzamelsoorten,1 variant,21 ondersoorten,1 forma.',)
# year observation_count: 55.037
# year individu_count: 1.592.230
# {'year': 1990, 'observation_count': 55037, 'individu_count': 1592230}
# Scraping year 1991
# year stats: ('51.357 waarnemingen van 1.643.209 individuen resulteerden in een lijst van332 soorten,4 hybrides,22 verzamelsoorten,1 variant,21 ondersoorten,3 forma.',)
# year observation_count: 51.357
# year individu_count: 1.643.209
# {'year': 1991, 'observation_count': 51357, 'individu_count': 1643209}
# Scraping year 1992
# year stats: ('50.693 waarnemingen van 1.630.980 individuen resulteerden in een lijst van330 soorten,6 hybrides,18 verzamelsoorten,1 variant,18 ondersoorten,3 forma.',)
# year observation_count: 50.693
# year individu_count: 1.630.980
# {'year': 1992, 'observation_count': 50693, 'individu_count': 1630980}
# Scraping year 1993
# year stats: ('60.247 waarnemingen van 1.922.223 individuen resulteerden in een lijst van337 soorten,6 hybrides,19 verzamelsoorten,1 synoniem,1 variant,23 ondersoorten,3 forma.',)
# year observation_count: 60.247
# year individu_count: 1.922.223
# {'year': 1993, 'observation_count': 60247, 'individu_count': 1922223}
# Scraping year 1994
# year stats: ('65.850 waarnemingen van 3.038.996 individuen resulteerden in een lijst van336 soorten,10 hybrides,22 verzamelsoorten,1 variant,50 ondersoorten,3 forma.',)
# year observation_count: 65.850
# year individu_count: 3.038.996
# {'year': 1994, 'observation_count': 65850, 'individu_count': 3038996}
# Scraping year 1995
# year stats: ('75.169 waarnemingen van 2.869.464 individuen resulteerden in een lijst van341 soorten,14 hybrides,25 verzamelsoorten,1 variant,25 ondersoorten,4 forma.',)
# year observation_count: 75.169
# year individu_count: 2.869.464
# {'year': 1995, 'observation_count': 75169, 'individu_count': 2869464}
# Scraping year 1996
# year stats: ('103.538 waarnemingen van 4.442.905 individuen resulteerden in een lijst van349 soorten,11 hybrides,28 verzamelsoorten,1 synoniem,60 ondersoorten,4 forma.',)
# year observation_count: 103.538
# year individu_count: 4.442.905
# {'year': 1996, 'observation_count': 103538, 'individu_count': 4442905}
# Scraping year 1997
# year stats: ('83.968 waarnemingen van 2.970.873 individuen resulteerden in een lijst van351 soorten,16 hybrides,20 verzamelsoorten,1 variant,68 ondersoorten,4 forma.',)
# year observation_count: 83.968
# year individu_count: 2.970.873
# {'year': 1997, 'observation_count': 83968, 'individu_count': 2970873}
# Scraping year 1998
# year stats: ('82.123 waarnemingen van 2.515.658 individuen resulteerden in een lijst van345 soorten,14 hybrides,28 verzamelsoorten,1 synoniem,59 ondersoorten,3 forma.',)
# year observation_count: 82.123
# year individu_count: 2.515.658
# {'year': 1998, 'observation_count': 82123, 'individu_count': 2515658}
# Scraping year 1999
# year stats: ('85.471 waarnemingen van 3.225.555 individuen resulteerden in een lijst van359 soorten,11 hybrides,23 verzamelsoorten,1 variant,73 ondersoorten,4 forma.',)
# year observation_count: 85.471
# year individu_count: 3.225.555
# {'year': 1999, 'observation_count': 85471, 'individu_count': 3225555}
# Scraping year 2000
# year stats: ('80.918 waarnemingen van 2.485.925 individuen resulteerden in een lijst van357 soorten,14 hybrides,18 verzamelsoorten,1 variant,76 ondersoorten,4 forma.',)
# year observation_count: 80.918
# year individu_count: 2.485.925
# {'year': 2000, 'observation_count': 80918, 'individu_count': 2485925}
# Scraping year 2001
# year stats: ('81.270 waarnemingen van 2.989.396 individuen resulteerden in een lijst van361 soorten,11 hybrides,21 verzamelsoorten,1 synoniem,1 variant,105 ondersoorten,5 forma.',)
# year observation_count: 81.270
# year individu_count: 2.989.396
# {'year': 2001, 'observation_count': 81270, 'individu_count': 2989396}
# Scraping year 2002
# year stats: ('94.668 waarnemingen van 2.574.634 individuen resulteerden in een lijst van352 soorten,14 hybrides,18 verzamelsoorten,1 synoniem,1 variant,102 ondersoorten,4 forma.',)
# year observation_count: 94.668
# year individu_count: 2.574.634
# {'year': 2002, 'observation_count': 94668, 'individu_count': 2574634}
# Scraping year 2003
# year stats: ('97.375 waarnemingen van 5.952.901 individuen resulteerden in een lijst van356 soorten,20 hybrides,18 verzamelsoorten,1 synoniem,1 variant,111 ondersoorten,4 forma.',)
# year observation_count: 97.375
# year individu_count: 5.952.901
# {'year': 2003, 'observation_count': 97375, 'individu_count': 5952901}
# Scraping year 2004
# year stats: ('110.885 waarnemingen van 3.593.855 individuen resulteerden in een lijst van359 soorten,16 hybrides,19 verzamelsoorten,1 variant,109 ondersoorten,4 forma.',)
# year observation_count: 110.885
# year individu_count: 3.593.855
# {'year': 2004, 'observation_count': 110885, 'individu_count': 3593855}
# Scraping year 2005
# year stats: ('114.798 waarnemingen van 3.783.117 individuen resulteerden in een lijst van354 soorten,14 hybrides,20 verzamelsoorten,1 synoniem,1 variant,109 ondersoorten,7 forma.',)
# year observation_count: 114.798
# year individu_count: 3.783.117
# {'year': 2005, 'observation_count': 114798, 'individu_count': 3783117}
# Scraping year 2006
# year stats: ('111.844 waarnemingen van 3.405.186 individuen resulteerden in een lijst van350 soorten,17 hybrides,23 verzamelsoorten,1 synoniem,1 variant,134 ondersoorten,4 forma.',)
# year observation_count: 111.844
# year individu_count: 3.405.186
# {'year': 2006, 'observation_count': 111844, 'individu_count': 3405186}
# Scraping year 2007
# year stats: ('128.122 waarnemingen van 4.018.464 individuen resulteerden in een lijst van352 soorten,16 hybrides,23 verzamelsoorten,1 synoniem,1 variant,119 ondersoorten,4 forma.',)
# year observation_count: 128.122
# year individu_count: 4.018.464
# {'year': 2007, 'observation_count': 128122, 'individu_count': 4018464}
# Scraping year 2008
# year stats: ('285.332 waarnemingen van 5.779.548 individuen resulteerden in een lijst van374 soorten,29 hybrides,26 verzamelsoorten,1 synoniem,1 variant,120 ondersoorten,6 forma.',)
# year observation_count: 285.332
# year individu_count: 5.779.548
# {'year': 2008, 'observation_count': 285332, 'individu_count': 5779548}
# Scraping year 2009
# year stats: ('696.443 waarnemingen van 10.263.969 individuen resulteerden in een lijst van390 soorten,35 hybrides,21 verzamelsoorten,1 synoniem,1 variant,104 ondersoorten,7 forma.',)
# year observation_count: 696.443
# year individu_count: 10.263.969
# {'year': 2009, 'observation_count': 696443, 'individu_count': 10263969}
# Scraping year 2010
# year stats: ('957.112 waarnemingen van 15.900.756 individuen resulteerden in een lijst van388 soorten,46 hybrides,25 verzamelsoorten,1 synoniem,1 variant,116 ondersoorten,6 forma.',)
# year observation_count: 957.112
# year individu_count: 15.900.756
# {'year': 2010, 'observation_count': 957112, 'individu_count': 15900756}
# Scraping year 2011
# year stats: ('1.110.214 waarnemingen van 18.006.820 individuen resulteerden in een lijst van385 soorten,46 hybrides,26 verzamelsoorten,1 synoniem,1 variant,111 ondersoorten,6 forma.',)
# year observation_count: 1.110.214
# year individu_count: 18.006.820
# {'year': 2011, 'observation_count': 1110214, 'individu_count': 18006820}
# Scraping year 2012
# year stats: ('1.239.243 waarnemingen van 17.747.453 individuen resulteerden in een lijst van396 soorten,49 hybrides,21 verzamelsoorten,1 synoniem,1 variant,110 ondersoorten,6 forma.',)
# year observation_count: 1.239.243
# year individu_count: 17.747.453
# {'year': 2012, 'observation_count': 1239243, 'individu_count': 17747453}
# Scraping year 2013
# year stats: ('1.331.236 waarnemingen van 21.511.687 individuen resulteerden in een lijst van397 soorten,52 hybrides,25 verzamelsoorten,1 synoniem,1 variant,105 ondersoorten,6 forma.',)
# year observation_count: 1.331.236
# year individu_count: 21.511.687
# {'year': 2013, 'observation_count': 1331236, 'individu_count': 21511687}
# Scraping year 2014
# year stats: ('1.488.234 waarnemingen van 23.065.662 individuen resulteerden in een lijst van398 soorten,48 hybrides,32 verzamelsoorten,1 synoniem,1 variant,124 ondersoorten,6 forma.',)
# year observation_count: 1.488.234
# year individu_count: 23.065.662
# {'year': 2014, 'observation_count': 1488234, 'individu_count': 23065662}
# Scraping year 2015
# year stats: ('1.711.651 waarnemingen van 62.139.358 individuen resulteerden in een lijst van407 soorten,60 hybrides,28 verzamelsoorten,1 synoniem,1 variant,127 ondersoorten,7 forma.',)
# year observation_count: 1.711.651
# year individu_count: 62.139.358
# {'year': 2015, 'observation_count': 1711651, 'individu_count': 62139358}
# Scraping year 2016
# year stats: ('1.864.999 waarnemingen van 17.873.919 individuen resulteerden in een lijst van413 soorten,60 hybrides,34 verzamelsoorten,1 synoniem,1 variant,123 ondersoorten,7 forma.',)
# year observation_count: 1.864.999
# year individu_count: 17.873.919
# {'year': 2016, 'observation_count': 1864999, 'individu_count': 17873919}
# Scraping year 2017
# year stats: ('2.079.958 waarnemingen van 19.165.061 individuen resulteerden in een lijst van425 soorten,60 hybrides,42 verzamelsoorten,1 synoniem,1 variant,125 ondersoorten,7 forma.',)
# year observation_count: 2.079.958
# year individu_count: 19.165.061
# {'year': 2017, 'observation_count': 2079958, 'individu_count': 19165061}
# Scraping year 2018
# year stats: ('2.208.089 waarnemingen van 20.509.547 individuen resulteerden in een lijst van432 soorten,62 hybrides,46 verzamelsoorten,1 synoniem,1 variant,139 ondersoorten,7 forma.',)
# year observation_count: 2.208.089
# year individu_count: 20.509.547
# {'year': 2018, 'observation_count': 2208089, 'individu_count': 20509547}
# Scraping year 2019
# year stats: ('2.453.732 waarnemingen van 21.459.569 individuen resulteerden in een lijst van425 soorten,64 hybrides,56 verzamelsoorten,1 synoniem,1 variant,174 ondersoorten,7 forma.',)
# year observation_count: 2.453.732
# year individu_count: 21.459.569
# {'year': 2019, 'observation_count': 2453732, 'individu_count': 21459569}
# Scraping year 2020
# year stats: ('3.440.886 waarnemingen van 25.425.947 individuen resulteerden in een lijst van450 soorten,69 hybrides,60 verzamelsoorten,2 synoniemen,1 variant,173 ondersoorten,7 forma.',)
# year observation_count: 3.440.886
# year individu_count: 25.425.947
# {'year': 2020, 'observation_count': 3440886, 'individu_count': 25425947}
# Scraping year 2021
# year stats: ('3.807.834 waarnemingen van 116.756.886 individuen resulteerden in een lijst van458 soorten,69 hybrides,61 verzamelsoorten,1 synoniem,1 variant,173 ondersoorten,7 forma.',)
# year observation_count: 3.807.834
# year individu_count: 116.756.886
# {'year': 2021, 'observation_count': 3807834, 'individu_count': 116756886}
# Scraping year 2022
# year stats: ('3.432.614 waarnemingen van 26.575.866 individuen resulteerden in een lijst van457 soorten,75 hybrides,65 verzamelsoorten,1 synoniem,1 variant,139 ondersoorten,7 forma.',)
# year observation_count: 3.432.614
# year individu_count: 26.575.866
# {'year': 2022, 'observation_count': 3432614, 'individu_count': 26575866}
# Scraping year 2023
# year stats: ('3.204.569 waarnemingen van 833.548.443 individuen resulteerden in een lijst van479 soorten,74 hybrides,58 verzamelsoorten,1 synoniem,1 variant,162 ondersoorten,7 forma.',)
# year observation_count: 3.204.569
# year individu_count: 833.548.443
# {'year': 2023, 'observation_count': 3204569, 'individu_count': 833548443}
# Scraping year 2024
# year stats: ('3.270.062 waarnemingen van 24.715.122 individuen resulteerden in een lijst van465 soorten,70 hybrides,68 verzamelsoorten,1 synoniem,1 variant,194 ondersoorten,7 forma.',)
# year observation_count: 3.270.062
# year individu_count: 24.715.122
# {'year': 2024, 'observation_count': 3270062, 'individu_count': 24715122}
# Scraped 54 years, last scraped year: 2024
# Scraping of yearly count of observations and individues is complete. Data saved to .csv file
