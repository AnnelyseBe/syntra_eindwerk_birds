# %%
import pandas as pd
import os

# %%
os.getcwd()
# set the max columns to none
pd.set_option('display.max_columns', None)
# set the max columns to none
pd.set_option('display.max_rows', None)
species_id =77

# %%
# file path
observation_details = f'scraped_data/cleaned/observation_details_{species_id}_clean_in_progress.csv'


# Load the data
df = pd.read_csv(observation_details, skipinitialspace=True, index_col=0)
df.head()
# Out:
#                 species_id species_name species_name_scientific  \
# observation_id
# 336207061               77       Bosuil             Strix aluco
# 336186286               77       Bosuil             Strix aluco
# 336212374               77       Bosuil             Strix aluco
# 336182552               77       Bosuil             Strix aluco
# 336182078               77       Bosuil             Strix aluco
#
#                                           validation  gps_coordinates  \
# observation_id
# 336207061       Goedgekeurd (automatische validatie)  50.5803, 5.4598
# 336186286       Goedgekeurd (automatische validatie)  50.3374, 4.8217
# 336212374       Goedgekeurd (automatische validatie)  51.0586, 4.9749
# 336182552       Goedgekeurd (automatische validatie)  51.3953, 4.4549
# 336182078       Goedgekeurd (automatische validatie)              NaN
#
#                accuracy   source              date amount life_stage  \
# observation_id
# 336207061            4m     Site  2024-12-31 17:50      1   onbekend
# 336186286            5m  ObsMapp        2024-12-31      1   onbekend
# 336212374            5m  ObsMapp  2024-12-31 06:53      1   onbekend
# 336182552           10m     Site        2024-12-31      1   onbekend
# 336182078           NaN  ObsMapp        2024-12-31      1   onbekend
#
#                           activity  location_id  \
# observation_id
# 336207061       baltsend / zingend      42217.0
# 336186286       baltsend / zingend      42452.0
# 336212374       baltsend / zingend      29060.0
# 336182552              slaapplaats     678810.0
# 336182078              slaapplaats     678810.0
#
#                                         location  observer_id  \
# observation_id
# 336207061                        Ivoz-Ramet (LG)      40377.0
# 336186286                             Bioul (NA)      44246.0
# 336212374               Veerle - Aartsbroek (AN)      63875.0
# 336182552       Grenspark Kalmthoutse Heide (AN)      41768.0
# 336182078       Grenspark Kalmthoutse Heide (AN)      40112.0
#
#                        observer_name counting_method    method
# observation_id
# 336207061           Charly Farinelle            geen  onbekend
# 336186286            Didier Cavelier        onbekend  onbekend
# 336212374          Anthony Hollebeke        onbekend   gehoord
# 336182552       Wouter Vanwesenbeeck            geen  onbekend
# 336182078                Bram Vogels        onbekend  onbekend

# %%
df.index
# Out:
# Index([336207061, 336186286, 336212374, 336182552, 336182078, 336196472,
#        336172421, 336169883, 336165558, 336159542,
#        ...
#        298898757, 298902920, 298906510, 304234478, 298898269, 298919351,
#        298873449, 298862341, 298863899, 299017969],
#       dtype='int64', name='observation_id', length=7577)

# %%
df.columns
# Out:
# Index(['species_id', 'species_name', 'species_name_scientific', 'validation',
#        'gps_coordinates', 'accuracy', 'source', 'date', 'amount', 'life_stage',
#        'activity', 'location_id', 'location', 'observer_id', 'observer_name',
#        'counting_method', 'method'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7577 entries, 336207061 to 299017969
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   species_id               7577 non-null   int64
#  1   species_name             7577 non-null   object
#  2   species_name_scientific  7577 non-null   object
#  3   validation               7577 non-null   object
#  4   gps_coordinates          7123 non-null   object
#  5   accuracy                 7121 non-null   object
#  6   source                   7577 non-null   object
#  7   date                     7577 non-null   object
#  8   amount                   7577 non-null   object
#  9   life_stage               7320 non-null   object
#  10  activity                 7320 non-null   object
#  11  location_id              7529 non-null   float64
#  12  location                 7529 non-null   object
#  13  observer_id              7529 non-null   float64
#  14  observer_name            7529 non-null   object
#  15  counting_method          7577 non-null   object
#  16  method                   7577 non-null   object
# dtypes: float64(2), int64(1), object(14)
# memory usage: 1.0+ MB

# %%
stats = df.describe(include='all')
stats
# Out:
#         species_id species_name species_name_scientific  \
# count       7577.0         7577                    7577
# unique         NaN            1                       1
# top            NaN       Bosuil             Strix aluco
# freq           NaN         7577                    7577
# mean          77.0          NaN                     NaN
# std            0.0          NaN                     NaN
# min           77.0          NaN                     NaN
# 25%           77.0          NaN                     NaN
# 50%           77.0          NaN                     NaN
# 75%           77.0          NaN                     NaN
# max           77.0          NaN                     NaN
#
#                                   validation  gps_coordinates accuracy  \
# count                                   7577             7123     7121
# unique                                     5             5955      111
# top     Goedgekeurd (automatische validatie)  50.7541, 4.5672       5m
# freq                                    5904              104     1525
# mean                                     NaN              NaN      NaN
# std                                      NaN              NaN      NaN
# min                                      NaN              NaN      NaN
# 25%                                      NaN              NaN      NaN
# 50%                                      NaN              NaN      NaN
# 75%                                      NaN              NaN      NaN
# max                                      NaN              NaN      NaN
#
#          source        date amount life_stage activity    location_id  \
# count      7577        7577   7577       7320     7320    7529.000000
# unique       10        5922     86          9       28            NaN
# top     ObsMapp  2024-04-12      1   onbekend  roepend            NaN
# freq       3212          17   6635       6072     2916            NaN
# mean        NaN         NaN    NaN        NaN      NaN   83067.426750
# std         NaN         NaN    NaN        NaN      NaN  136435.933058
# min         NaN         NaN    NaN        NaN      NaN   23091.000000
# 25%         NaN         NaN    NaN        NaN      NaN   27482.000000
# 50%         NaN         NaN    NaN        NaN      NaN   30791.000000
# 75%         NaN         NaN    NaN        NaN      NaN   43592.000000
# max         NaN         NaN    NaN        NaN      NaN  724090.000000
#
#                          location   observer_id   observer_name  \
# count                        7529  7.529000e+03            7529
# unique                       2278           NaN            2096
# top     Tombeek - Laanvallei (VB)           NaN  Frederik Fluyt
# freq                          166           NaN             179
# mean                          NaN  1.569988e+05             NaN
# std                           NaN  2.059305e+05             NaN
# min                           NaN  1.660000e+02             NaN
# 25%                           NaN  4.140000e+04             NaN
# 50%                           NaN  7.774800e+04             NaN
# 75%                           NaN  1.592400e+05             NaN
# max                           NaN  1.059786e+06             NaN
#
#        counting_method    method
# count             7577      7577
# unique               7        13
# top           onbekend  onbekend
# freq              4169      3582
# mean               NaN       NaN
# std                NaN       NaN
# min                NaN       NaN
# 25%                NaN       NaN
# 50%                NaN       NaN
# 75%                NaN       NaN
# max                NaN       NaN

# %%
stats['amount']
# Out:
# count     7577
# unique      86
# top          1
# freq      6635
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN
# Name: amount, dtype: object

# %%
df.isnull().sum()
# Out:
# species_id                   0
# species_name                 0
# species_name_scientific      0
# validation                   0
# gps_coordinates            454
# accuracy                   456
# source                       0
# date                         0
# amount                       0
# life_stage                 257
# activity                   257
# location_id                 48
# location                    48
# observer_id                 48
# observer_name               48
# counting_method              0
# method                       0
# dtype: int64

# %%
# Kijken welke mogelijke waarden er zijn, en wat de frequentie in de andere kolommen is
df.groupby('validation').nunique()
# Out:
#                                       species_id  species_name  \
# validation
# (nog) niet te beoordelen                       1             1
# Goedgekeurd (aannemelijk)                      1             1
# Goedgekeurd (automatische validatie)           1             1
# Goedgekeurd (met bewijs)                       1             1
# Onbekend                                       1             1
#
#                                       species_name_scientific  \
# validation
# (nog) niet te beoordelen                                    1
# Goedgekeurd (aannemelijk)                                   1
# Goedgekeurd (automatische validatie)                        1
# Goedgekeurd (met bewijs)                                    1
# Onbekend                                                    1
#
#                                       gps_coordinates  accuracy  source  date  \
# validation
# (nog) niet te beoordelen                           22        13       3    23
# Goedgekeurd (aannemelijk)                          23        13       3    37
# Goedgekeurd (automatische validatie)             4628        96      10  4741
# Goedgekeurd (met bewijs)                          159        35       4   213
# Onbekend                                         1177        69       8  1211
#
#                                       amount  life_stage  activity  \
# validation
# (nog) niet te beoordelen                   1           1         2
# Goedgekeurd (aannemelijk)                  3           3         4
# Goedgekeurd (automatische validatie)      77           9        24
# Goedgekeurd (met bewijs)                   8           5        16
# Onbekend                                  20           4        21
#
#                                       location_id  location  observer_id  \
# validation
# (nog) niet te beoordelen                       23        23           22
# Goedgekeurd (aannemelijk)                      26        26           25
# Goedgekeurd (automatische validatie)         1719      1719         1619
# Goedgekeurd (met bewijs)                      152       152          151
# Onbekend                                      702       702          727
#
#                                       observer_name  counting_method  method
# validation
# (nog) niet te beoordelen                         22                2       5
# Goedgekeurd (aannemelijk)                        25                3       6
# Goedgekeurd (automatische validatie)           1613                7      11
# Goedgekeurd (met bewijs)                        151                5       7
# Onbekend                                        725                6      13

# %%
df['amount'].value_counts()
# Out:
# amount
# 1                                                                                                                                                                                                                                                                                                                               6635
# 2                                                                                                                                                                                                                                                                                                                                575
# 3                                                                                                                                                                                                                                                                                                                                 93
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                     46
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                                30
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                                        28
# 4                                                                                                                                                                                                                                                                                                                                 14
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                      12
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                          11
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                                                                                                                                            11
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            bezet nest met jongen\n            \n        \n            2\n            pullus\n            \n\n\n\n\n\n    \n\n\n            bezet nest met jongen                                                                                                          8
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                            6
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                                                                                                                                                  6
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            bezet nest met jongen\n            \n        \n            1\n            pullus\n            \n\n\n\n\n\n    \n\n\n            bezet nest met jongen                                                                                                          5
# 1\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                    4
# 2\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                      4
# 2\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                                                                                                                                             4
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            3\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                   3
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                 3
# 2\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                                                                                                                                                         3
# 1\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                                                                                                                                     3
# 5                                                                                                                                                                                                                                                                                                                                  2
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            2\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                            2
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                                      2
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                                                                                                                                        2
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                             2
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            bezet nest met jongen\n            \n        \n            3\n            pullus\n            \n\n\n\n\n\n    \n\n\n            bezet nest met jongen                                                                                                          2
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                               2
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                                  2
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                 1
# 2\n            \n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            2\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                                 1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            2\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                                      1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                                  1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            adult in broedbiotoop                                                                                                                        1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            2\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                                 1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                                 1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                            1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            2\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                           1
# 2\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                           1
# 6                                                                                                                                                                                                                                                                                                                                  1
# 2\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                                        1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                                             1
# 2\n            \n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            4\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                                      1
# 2\n            adult\n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend                                                                                                                 1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            2\n            eerste zomer\n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                        1
# 2\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                                         1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                                                                                                                                                         1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            adult in broedbiotoop\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            adult in broedbiotoop                                                                                                                     1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            pullus\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            overvliegend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            overvliegend                                                                                                                                       1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            alarmerend                                                                                                                                                                                                                                                          1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            2\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                                         1
# 2\n            adult\n            \n\n\n\n\n\n    \n\n\n            baltsend / zingend\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                            1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            paar in broedbiotoop\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            paar in broedbiotoop                                                                                                                       1
# 2\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                     1
# 4\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            pas uitgevlogen/dons jongen\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                            1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                     1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                            1
# 2\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                                                                                                                                     1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            2\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            pas uitgevlogen/dons jongen                                                                                                            1
# 3\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                    1
# 2\n            \n            \n\n\n\n\n\n    \n\n\n            pas uitgevlogen/dons jongen\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            alarmerend                                                                                                                     1
# 2\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                            1
# 2\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                                                                                                                                                 1
# 2\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                    1
# 3\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                            1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            pullus\n            \n\n\n\n\n\n    \n\n\n            bezet nest met jongen                                                                                                                    1
# 2\n            \n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            3\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                                 1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            2\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                    1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            pullus\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                      1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            bezet nest met jongen\n            \n        \n            2\n            pullus\n            \n\n\n\n\n\n    \n\n\n            pas uitgevlogen/dons jongen                                                                                                    1
# 2\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            pas uitgevlogen/dons jongen\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            pas uitgevlogen/dons jongen                                                                                            1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            2\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            ter plaatse       1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            4\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                            1
# 3\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            2\n            \n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                                         1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            3\n            pullus\n            \n\n\n\n\n\n    \n\n\n            bezet nest met jongen                                                                                                                    1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            rustend\n            \n        \n            3\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            rustend                                                                                                                                    1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            adult in broedbiotoop\n            \n        \n            3\n            \n            \n\n\n\n\n\n    \n\n\n            pas uitgevlogen/dons jongen                                                                                                               1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            overvliegend                                                                                                                                       1
# 2\n            \n            \n\n\n\n\n\n    \n\n\n            adult in broedbiotoop                                                                                                                                                                                                                                               1
# 1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend paar (ook paring)\n            \n        \n            1\n            \n            \n\n\n\n\n\n    \n\n\n            baltsend paar (ook paring)                                                                                                           1
# 2\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            bezet nest met jongen                                                                                                                                                                                                                                       1
# 2\n            \n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            4\n            \n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                                 1
# 1\n            juveniel\n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                                                                                                                                                 1
# 1\n            adult\n            \n\n\n\n\n\n    \n\n\n            roepend\n            \n        \n            2\n            pullus\n            \n\n\n\n\n\n    \n\n\n            roepend                                                                                                                                      1
# 2\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse\n            \n        \n            2\n            adult\n            \n\n\n\n\n\n    \n\n\n            ter plaatse                                                                                                                               1
# Name: count, dtype: int64
